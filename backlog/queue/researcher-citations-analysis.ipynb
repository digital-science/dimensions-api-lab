# %% [markdown]
# # Researcher citations analysis
# This Python notebook shows how to use the [Dimensions Analytics API](https://www.dimensions.ai/dimensions-apis/) in order to ...

# %% [markdown]
# ## Prerequisites
#
# This notebook assumes you have installed the [Dimcli](https://pypi.org/project/dimcli/) library and are familiar with the *Getting Started* tutorial.

# %%
# !pip install dimcli --quiet 

import dimcli
from dimcli.shortcuts import *
import json
import sys
import pandas as pd
import plotly.express as px
if not 'google.colab' in sys.modules:
  # make js dependecies local / needed by html exports
  from plotly.offline import init_notebook_mode
  init_notebook_mode(connected=True)
#

print("==\nLogging in..")
# https://github.com/digital-science/dimcli#authentication
ENDPOINT = "https://app.dimensions.ai"
if 'google.colab' in sys.modules:
  import getpass
  USERNAME = getpass.getpass(prompt='Username: ')
  PASSWORD = getpass.getpass(prompt='Password: ')    
  dimcli.login(USERNAME, PASSWORD, ENDPOINT)
else:
  USERNAME, PASSWORD  = "", ""
  dimcli.login(USERNAME, PASSWORD, ENDPOINT)
dsl = dimcli.Dsl()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ==
# Logging in..
# Dimcli - Dimensions API Client (v0.7.1)
# Connected to: https://app.dimensions.ai - DSL v1.25
# Method: dsl.ini file

# %% [markdown]
# ## 1. Getting outgoing citations (references) for a researcher
#
#
# * see [6-Working-with-lists.html](https://api-lab.dimensions.ai/cookbooks/1-getting-started/6-Working-with-lists.html)

# %% [markdown]
# Eg https://app.dimensions.ai/discover/publication?and_facet_researcher=ur.01372572360.83

# %%
RESID = "ur.01372572360.83" #@param {type:"string"}

query = f"""
search publications 
    where researchers.id="{RESID}" return publications[id+title+reference_ids]
"""

print("===\nQuery:\n", query)     
print("===\nRetrieving authored publications .. ")
researcher_pubs = dsl.query_iterative(query).as_dataframe()


#
# focus on references 
#

#
# Let's extract all referenced articles, and sort them by how many times they are referenced. 
# remember that Dimensions keeps track only of references that have a DOI
#


ref_ids = researcher_pubs.explode("reference_ids").dropna().groupby('reference_ids', as_index=False).count()[['reference_ids', 'id']]
ref_ids = ref_ids.rename(columns={'reference_ids' : 'id', 'id' : 'citations'})
print("===\nTotal referenced publications: ", len(ref_ids))
print("===\nRetrieving referenced publications, 250 at a time.. \n")

ids_chunks = chunks_of(list(ref_ids.id), 250) 

data = []
for c in ids_chunks:

    res = dsl.query_iterative(f"""
                     search publications
                        where id in {json.dumps(c)}
                        return publications
                    """)
    data += res.publications

#        
# finally, turn the pubs_list JSON into a Dimcli Dataset  
#

results = DslDataset.from_publications_list(data)
# Out:
# ===
# Query:
#
# search publications
#     where researchers.id="ur.01372572360.83" return publications[id+title+reference_ids]
#
# ===
# Retrieving authored publications ..
# 1000 / ...
# 50 / 50
# ===
# Records extracted: 50
# ===
# Total referenced publications:  182
# ===
# Retrieving referenced publications, 250 at a time..
#
# 1000 / ...
# 182 / 182
# ===
# Records extracted: 182

# %% [markdown]
# ### Most cited publications

# %%
references = results.as_dataframe()
references = references.merge(ref_ids, on="id").sort_values('citations', ascending=False)
references['url'] = references.apply(lambda x: dimensions_url(x['id']),  axis=1)
references.head(10)
# Out:
#      year              id     type      pages  \
# 70   1986  pub.1046809313  article      89-89
# 126  1977  pub.1036186182  article     95-110
# 84   1984  pub.1033269614  article      75-92
# 123  1977  pub.1061472102  article    452-458
# 89   1984  pub.1062103690  article      75-81
# 72   1986  pub.1062622623  article  1292-1294
# 146  1973  pub.1019025254  article    191-242
# 145  1973  pub.1034061036  article    313-314
# 73   1986  pub.1061308618  article      70-82
# 112  1979  pub.1062228853  article    583-592
#
#                                    author_affiliations  \
# 70   [[{'first_name': 'Marc H.', 'last_name': 'Raib...
# 126  [[{'first_name': 'H.', 'last_name': 'Hemami', ...
# 84   [[{'first_name': 'Marc H.', 'last_name': 'Raib...
# 123  [[{'first_name': 'H.', 'last_name': 'Hemami', ...
# 89   [[{'first_name': 'M. H.', 'last_name': 'Raiber...
# 72   [[{'first_name': 'M H', 'last_name': 'Raibert'...
# 146  [[{'first_name': 'Miomir', 'last_name': 'Vukob...
# 145  [[{'first_name': 'TERENCE J.', 'last_name': 'D...
# 73   [[{'first_name': 'M.', 'last_name': 'Raibert',...
# 112  [[{'first_name': 'Cliff', 'last_name': 'Frohli...
#
#                                                  title volume issue  \
# 70                          Legged Robots That Balance      1     4
# 126          The inverted pendulum and biped stability     34   1-2
# 84   Experiments in Balance with a 3D One-Legged Ho...      3     2
# 123  Postural and gait stability of a planar five l...     22     3
# 89   Experiments in Balance With a 2D One-Legged Ho...    106     1
# 72                                 Symmetry in running    231  4743
# 146  Mathematical models of general anthropomorphic...     17   3-4
# 145          Energetic Cost of Locomotion in Kangaroos    246  5431
# 73        Running on four legs as though they were one      2     2
# 112  Do springboard divers violate angular momentum...     47     7
#
#        journal.id                                      journal.title  \
# 70   jour.1033604                           IEEE Intelligent Systems
# 126  jour.1007478                           Mathematical Biosciences
# 84   jour.1041772     The International Journal of Robotics Research
# 123  jour.1033500             IEEE Transactions on Automatic Control
# 89   jour.1026140  Journal of Dynamic Systems Measurement and Con...
# 72   jour.1346339                                            Science
# 146  jour.1007478                           Mathematical Biosciences
# 145  jour.1018957                                             Nature
# 73   jour.1143897            IEEE Journal on Robotics and Automation
# 112  jour.1056671                        American Journal of Physics
#
#      citations                                                url
# 70           8  https://app.dimensions.ai/details/publication/...
# 126          5  https://app.dimensions.ai/details/publication/...
# 84           5  https://app.dimensions.ai/details/publication/...
# 123          5  https://app.dimensions.ai/details/publication/...
# 89           5  https://app.dimensions.ai/details/publication/...
# 72           5  https://app.dimensions.ai/details/publication/...
# 146          4  https://app.dimensions.ai/details/publication/...
# 145          4  https://app.dimensions.ai/details/publication/...
# 73           4  https://app.dimensions.ai/details/publication/...
# 112          3  https://app.dimensions.ai/details/publication/...

# %%
# for colab users: save to a google sheet
if COLAB_ENV:
    MYDF = references
    title = f"Publications cited by {RESID}"
    from google.colab import auth
    auth.authenticate_user()

    import gspread
    from gspread_dataframe import get_as_dataframe, set_with_dataframe
    from oauth2client.client import GoogleCredentials

    gc = gspread.authorize(GoogleCredentials.get_application_default())
    sh = gc.create(title)
    worksheet = gc.open(title).sheet1
    set_with_dataframe(worksheet, MYDF)
    spreadsheet_url = "https://docs.google.com/spreadsheets/d/%s" % sh.id
    print(spreadsheet_url)

# %% [markdown]
# ### Most cited authors
#
# * an authors dataframe can be obtained simply by using Dimcli's `as_dataframe_authors` method
# * we group the authors using 3 fields: "researcher_id", "first_name", "last_name"
# * don't be surprised if you find the same researchers at the top of the list! self-citations are quite a common thing..
# * like before, we generate a nice Dimensions URL in case you want to follow up on these authors

# %%
authors = results.as_dataframe_authors()\
    .groupby(["researcher_id", "first_name", "last_name"], as_index=False)\
    .count().sort_values("pub_id", ascending=False)\
    .dropna(subset=['researcher_id'])[['researcher_id', 'first_name', 'last_name', 'pub_id']]
authors.rename(columns={'pub_id' : 'citations'}, inplace=True)
authors['url'] = authors.apply(lambda x: dimensions_url(x['researcher_id']), axis=1)
authors.head(20)
# Out:
#           researcher_id  first_name   last_name  citations  \
# 292   ur.01372572360.83     Marc H.     Raibert         10
# 147   ur.01013753617.38          H.      Hemami          9
# 289   ur.01372572360.83       M. H.     Raibert          5
# 404   ur.07506450371.42     R. McN.   Alexander          4
# 142  ur.010040341511.95  G. Melvill       Jones          4
# 176   ur.01063256350.86          A.   Takanishi          3
# 148   ur.01013753617.38    Hooshang      Hemami          3
# 190   ur.01107565641.99   Thomas A.     McMahon          3
# 396   ur.07423063205.32    Masahiro      Fujita          3
# 357  ur.016432514545.06   Yoshihiro      Kuroki          3
# 101                          Milton  Hildebrand          3
# 144   ur.01010754165.86       Simon      Mochon          2
# 91                               M.   Masubuchi          2
# 389    ur.0672403675.81          M.     Herbert          2
# 383    ur.0644140707.01          A.     Gonshor          2
# 333  ur.015734206461.77       Maxim   Likhachev          2
# 184   ur.01100165303.60         L E      Rosser          2
# 375    ur.0606616172.01  Jessica K.     Hodgins          2
# 252  ur.012614726653.11   Robert B.      McGhee          2
# 328  ur.015474057357.21          I.        Kato          2
#
#                                                    url
# 292  https://app.dimensions.ai/discover/publication...
# 147  https://app.dimensions.ai/discover/publication...
# 289  https://app.dimensions.ai/discover/publication...
# 404  https://app.dimensions.ai/discover/publication...
# 142  https://app.dimensions.ai/discover/publication...
# 176  https://app.dimensions.ai/discover/publication...
# 148  https://app.dimensions.ai/discover/publication...
# 190  https://app.dimensions.ai/discover/publication...
# 396  https://app.dimensions.ai/discover/publication...
# 357  https://app.dimensions.ai/discover/publication...
# 101                                               None
# 144  https://app.dimensions.ai/discover/publication...
# 91                                                None
# 389  https://app.dimensions.ai/discover/publication...
# 383  https://app.dimensions.ai/discover/publication...
# 333  https://app.dimensions.ai/discover/publication...
# 184  https://app.dimensions.ai/discover/publication...
# 375  https://app.dimensions.ai/discover/publication...
# 252  https://app.dimensions.ai/discover/publication...
# 328  https://app.dimensions.ai/discover/publication...

# %%
# for colab users: save to a google sheet
if COLAB_ENV:
    MYDF = authors
    title = f"Authors cited by {RESID}"
    from google.colab import auth
    auth.authenticate_user()

    import gspread
    from gspread_dataframe import get_as_dataframe, set_with_dataframe
    from oauth2client.client import GoogleCredentials
    
    gc = gspread.authorize(GoogleCredentials.get_application_default())
    sh = gc.create(title)
    worksheet = gc.open(title).sheet1
    set_with_dataframe(worksheet, MYDF)
    spreadsheet_url = "https://docs.google.com/spreadsheets/d/%s" % sh.id
    print(spreadsheet_url)

# %% [markdown]
# ## Conclusion
#
# In this tutorial we have demonstrated how to query for ... using the [Dimensions Analytics API](https://www.dimensions.ai/dimensions-apis/).
