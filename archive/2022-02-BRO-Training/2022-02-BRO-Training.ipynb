# %% [markdown]
# # 2022-03 DoD Training
#
# Outline
#
# 1. The Grants data model - quick walkthrough
# 2. Useful queries from a Funder GRID ID
# 3. Querying using arbitrary lists of IDs

# %% [markdown]
# ## Prerequisites
#
# This notebook assumes you have installed the [Dimcli](https://pypi.org/project/dimcli/) library and are familiar with the [API LAB](https://api-lab.dimensions.ai/) *Getting Started* tutorials.

# %%
# !pip install dimcli --quiet 

import dimcli
from dimcli.utils import *
import json
import sys
import pandas as pd

import plotly.express as px
from IPython.display import Image

print("==\nLogging in..")

ENDPOINT = "https://app.dimensions.ai"

if 'google.colab' in sys.modules:
  import getpass
  KEY = getpass.getpass(prompt='API Key: ')  
  dimcli.login(key=KEY, endpoint=ENDPOINT)
else:
  KEY = ""
  dimcli.login()

dsl = dimcli.Dsl()
# Out:
# Searching config file credentials for default 'live' instance..
# ==
# Logging in..
# Dimcli - Dimensions API Client (v0.9.6)
# Connected to: <https://app.dimensions.ai/api/dsl/v2> - DSL v2.0
# Method: dsl.ini file

# %% [markdown]
# ## 1. The grants data model - quick walkthrough

# %% [markdown]
# Fields reference: https://docs.dimensions.ai/dsl/datasource-grants.html

# %% [markdown]
# ### 1.1 Dimensions grant `ID` VS 'original' `grant_number`

# %%
# %%dsldf
#
# search grants
#     for "detector AND chemicals"
# return grants[id+grant_number+title] limit 5
# Out:
# Returned Grants: 5 (total = 4323)
# Time: 1.10s
#    grant_number             id  \
# 0       2143485  grant.9971026
# 1       2150517  grant.9967366
# 2  ST/W000830/1  grant.9971907
# 3       2151709  grant.9971074
# 4        201547  grant.9993718
#
#                                                title
# 0  CAREER: Going Beyond Linear Models for Attack ...
# 1  REU Site: Multidisciplinary Underground Scienc...
# 2  A Programme of Technology, Astrophysics and Co...
# 3  I-Corps: A fluorescence sensor for early detec...
# 4  Quantum-limited metrology, transduction and ge...

# %% [markdown]
# Once you have the IDs, you can search using them - especially when using related models e.g. publications, patents etc.. (more on this in the next section).

# %%
# %%dsldf
#
# search grants
#     where id in ["grant.9971026", "grant.9967366"]
#     or grant_number in ["ST/W000830/1", "2151709", "201547"]
# return grants[id+grant_number+title]
# Out:
# Returned Grants: 5 (total = 5)
# Time: 0.70s
#    grant_number             id  \
# 0       2143485  grant.9971026
# 1       2150517  grant.9967366
# 2  ST/W000830/1  grant.9971907
# 3       2151709  grant.9971074
# 4        201547  grant.9993718
#
#                                                title
# 0  CAREER: Going Beyond Linear Models for Attack ...
# 1  REU Site: Multidisciplinary Underground Scienc...
# 2  A Programme of Technology, Astrophysics and Co...
# 3  I-Corps: A fluorescence sensor for early detec...
# 4  Quantum-limited metrology, transduction and ge...

# %% [markdown]
# ### 1.2 Field types: atomic data type (`funding_org_name`)  VS lists (`funder_countries`) VS entities (eg `funders`)

# %%
# %%dsldf
#
# search grants
#     for "detector AND chemicals"
# return grants[id+funding_org_name+funder_countries+funders] limit 5
# Out:
# Returned Grants: 5 (total = 4323)
# Time: 1.18s
#                            funder_countries  \
# 0   [{'id': 'US', 'name': 'United States'}]
# 1   [{'id': 'US', 'name': 'United States'}]
# 2  [{'id': 'GB', 'name': 'United Kingdom'}]
# 3   [{'id': 'US', 'name': 'United States'}]
# 4     [{'id': 'CH', 'name': 'Switzerland'}]
#
#                                              funders  \
# 0  [{'acronym': 'NSF ENG', 'city_name': 'Arlingto...
# 1  [{'acronym': 'NSF MPS', 'city_name': 'Arlingto...
# 2  [{'acronym': 'STFC', 'city_name': 'Swindon', '...
# 3  [{'acronym': 'NSF ENG', 'city_name': 'Arlingto...
# 4  [{'acronym': 'SNF', 'city_name': 'Bern', 'coun...
#
#                                    funding_org_name             id
# 0                       Directorate for Engineering  grant.9971026
# 1  Directorate for Mathematical & Physical Sciences  grant.9967366
# 2         Science and Technology Facilities Council  grant.9971907
# 3                       Directorate for Engineering  grant.9971074
# 4                 Swiss National Science Foundation  grant.9993718

# %% [markdown]
# Use `unnest(funders)` or `unnest(funder_countries)` to unpack the contents of complex fields (docs:https://docs.dimensions.ai/dsl/language.html#unnesting-multi-value-entity-fields)

# %%
# %%dsldf
#
# search grants
#     for "detector AND chemicals"
# return grants[id+funding_org_name+unnest(funder_countries)] limit 5
# Out:
# Returned objects: 5 (total grants= 4323)
# Time: 0.96s
#   funder_countries.id funder_countries.name  \
# 0                  US         United States
# 1                  US         United States
# 2                  GB        United Kingdom
# 3                  US         United States
# 4                  CH           Switzerland
#
#                                    funding_org_name             id
# 0                       Directorate for Engineering  grant.9971026
# 1  Directorate for Mathematical & Physical Sciences  grant.9967366
# 2         Science and Technology Facilities Council  grant.9971907
# 3                       Directorate for Engineering  grant.9971074
# 4                 Swiss National Science Foundation  grant.9993718

# %%
# %%dsldf
#
# search grants
#     for "detector AND chemicals"
# return grants[id+unnest(funders)] limit 5
# Out:
# Returned objects: 5 (total grants= 4323)
# Time: 1.18s
#   funders.acronym funders.city_name funders.country_name     funders.id  \
# 0         NSF ENG         Arlington        United States  grid.457810.f
# 1         NSF MPS         Arlington        United States  grid.457875.c
# 2            STFC           Swindon       United Kingdom  grid.14467.30
# 3         NSF ENG         Arlington        United States  grid.457810.f
# 4             SNF              Bern          Switzerland  grid.425888.b
#
#    funders.latitude                             funders.linkout  \
# 0         38.880580  [http://www.nsf.gov/dir/index.jsp?org=ENG]
# 1         38.880566  [http://www.nsf.gov/dir/index.jsp?org=MPS]
# 2         51.566532                    [http://www.stfc.ac.uk/]
# 3         38.880580  [http://www.nsf.gov/dir/index.jsp?org=ENG]
# 4         46.949230                      [http://www.snf.ch/en]
#
#    funders.longitude                                      funders.name  \
# 0         -77.111000                       Directorate for Engineering
# 1         -77.110990  Directorate for Mathematical & Physical Sciences
# 2          -1.785539         Science and Technology Facilities Council
# 3         -77.111000                       Directorate for Engineering
# 4           7.432395                 Swiss National Science Foundation
#
#   funders.state_name funders.types             id
# 0           Virginia  [Government]  grant.9971026
# 1           Virginia  [Government]  grant.9967366
# 2                NaN  [Government]  grant.9971907
# 3           Virginia  [Government]  grant.9971074
# 4                NaN  [Government]  grant.9993718

# %% [markdown]
# ### 1.3 Funder GRID identifiers (`funders.id`)

# %% [markdown]
# Let's find the GRID identifier we are interested in, using the [organizations API](https://docs.dimensions.ai/dsl/datasource-organizations.html)).

# %%
# %%dsldf
#
# search organizations for "Department of Defense"
#     where country_name="United States" and types in ["Government"]
# return organizations limit 100
# Out:
# Returned Organizations: 2 (total = 2)
# Time: 0.71s
#          city_name   country_name             id   latitude  \
# 0         Honolulu  United States  grid.448529.6  21.261510
# 1  Washington D.C.  United States  grid.420391.d  38.871113
#
#                      linkout  longitude                                 name  \
# 0   [http://dod.hawaii.gov/] -157.79582         Hawaii Department of Defense
# 1  [http://www.defense.gov/]  -77.05583  United States Department of Defense
#
#              state_name         types acronym
# 0                Hawaii  [Government]     NaN
# 1  District of Columbia  [Government]  USDOD

# %% [markdown]
# Now let's find **grants** data using `grid.420391.d`

# %%
# %%dsldf
#
# search grants for "detector AND chemicals"
#     where funders.id = "grid.420391.d"
# return grants limit 5
# Out:
# Returned Grants: 5 (total = 67)
# Time: 0.67s
#           active_year    end_date  \
# 0  [2019, 2020, 2021]  2021-08-07
# 1  [2019, 2020, 2021]  2021-07-18
# 2              [2019]  2019-07-27
# 3  [2018, 2019, 2020]  2020-11-20
# 4  [2018, 2019, 2020]  2020-11-20
#
#                                              funders  \
# 0  [{'acronym': 'USDOD ', 'city_name': 'Washingto...
# 1  [{'acronym': 'USDOD ', 'city_name': 'Washingto...
# 2  [{'acronym': 'USDOD ', 'city_name': 'Washingto...
# 3  [{'acronym': 'USDOD ', 'city_name': 'Washingto...
# 4  [{'acronym': 'USDOD ', 'city_name': 'Washingto...
#
#                       funding_org_name       grant_number             id  \
# 0  United States Department of Defense  W911-SR-19-C-0033  grant.9526622
# 1  United States Department of Defense  W911-NF-19-C-0068  grant.9526646
# 2  United States Department of Defense   W911QY-19-P-0011  grant.9526613
# 3  United States Department of Defense   W911SR-19-C-0003  grant.9526626
# 4  United States Department of Defense   W911SR-19-C-0003  grant.8579322
#
#   language                                     original_title  start_date  \
# 0       en  MicroLens Hyperspectral Imager for Standoff Ch...  2019-08-08
# 1       en  Detection of “active” biological toxins by exp...  2019-07-19
# 2       en  High stretch, environmentally robust hybridsil...  2019-01-28
# 3       en  Photoacoustic Gasses Optical Detector and Anal...  2018-11-21
# 4       en  Photoacoustic Gasses Optical Detector and Anal...  2018-11-21
#
#    start_year                                              title
# 0        2019  MicroLens Hyperspectral Imager for Standoff Ch...
# 1        2019  Detection of “active” biological toxins by exp...
# 2        2019  High stretch, environmentally robust hybridsil...
# 3        2018  Photoacoustic Gasses Optical Detector and Anal...
# 4        2018  Photoacoustic Gasses Optical Detector and Anal...

# %% [markdown]
# ## 2. Useful queries using a Funder GRID identifier

# %%
Image(url= "https://docs.dimensions.ai/dsl/_images/data-model-grants.png", width=1000)
# Out:
# <img src="https://docs.dimensions.ai/dsl/_images/data-model-grants.png" width="1000"/>

# %% [markdown]
# ### 2.1 How many grants?
#
# The total number of results should match [what you see in Dimensions](https://app.dimensions.ai/discover/publication?search_mode=content&and_facet_funder=grid.420391.d).

# %%
# %%dsldf
#
# search grants
#     where funders.id = "grid.420391.d"
# return grants[id+title]
# Out:
# Returned Grants: 20 (total = 2436)
# Time: 0.55s
#                id                                              title
# 0   grant.9785941  Rethinking Mathematics through the Integration...
# 1   grant.9881724  The Knowing and Embracing World Languages (KEW...
# 2   grant.9881723                                  Project H.E.L.L.O
# 3   grant.9881722          VBCPS Spanish Immersion Expansion Project
# 4   grant.9881721                                           PASSPORT
# 5   grant.9881720                           Computer Science for All
# 6   grant.9881719                                   STEALTH Sciences
# 7   grant.9881718  Bilingual, Biliterate, Bicultural Pathways to ...
# 8   grant.9881717                                    Healthy Knights
# 9   grant.9881716            Future Ready with Biomedical Innovation
# 10  grant.9881715  Raise the Bar: An engaging approach to whole-c...
# 11  grant.9881714             STEM Innovation - Unlock the Discovery
# 12  grant.9881713  Project BrainISE: Inspiring Science Excellence...
# 13  grant.9843160                                World Language Plus
# 14  grant.9843159  Putting the M in STEM Growing Mathematical Thi...
# 15  grant.9785949                         Belle Chasse Academy Grant
# 16  grant.9785948  Exploration of Engineering Through Health Science
# 17  grant.9785947                                 Project Resilience
# 18  grant.9785946  Career Pathways: Developing STEM and CTE Learn...
# 19  grant.9785945  STEM-M Strategic Teaching to Engage Military M...

# %% [markdown]
# ### 2.2 Downloading all grants records
#
# We can use a little Python and the `query_iterative` method.

# %%
# %%dslloopdf
#
# search grants
#     where funders.id = "grid.420391.d"
# return grants[id+title]
# Out:
# Starting iteration with limit=1000 skip=0 ...
# 0-1000 / 2436 (0.65s)
# 1000-2000 / 2436 (0.59s)
# 2000-2436 / 2436 (0.58s)
# ===
# Records extracted: 2436
#                  id                                              title
# 0     grant.9785941  Rethinking Mathematics through the Integration...
# 1     grant.9881724  The Knowing and Embracing World Languages (KEW...
# 2     grant.9881723                                  Project H.E.L.L.O
# 3     grant.9881722          VBCPS Spanish Immersion Expansion Project
# 4     grant.9881721                                           PASSPORT
# ...             ...                                                ...
# 2431  grant.4400529  Advanced Column and Accumulator for Low Power ...
# 2432  grant.4399002  Deve;opment of A Handheld Gas Chromatography/M...
# 2433  grant.4398776  Large Scale Production of Antibodies in Transg...
# 2434  grant.4398540                       Water-Based Ensemble Coating
# 2435  grant.4398210  Biological Threat Identification Employing For...
#
# [2436 rows x 2 columns]

# %% [markdown]
# Save the data so that we can reuse it later.

# %%
all_grants = dsl_last_results

# %% [markdown]
# ### 2.3 Now that we have the query, we can experiment with other facets..
#
# #### Top organizations
#
# Change the final query bit to return `research_orgs`

# %%
# %%dsldf
#
# search grants
#     where funders.id = "grid.420391.d"
#     and active_year >= 2010
# return research_orgs
# aggregate funding
# limit 1000
# Out:
# Returned Research_orgs: 522
# Time: 0.92s
#            city_name  count   country_name     funding             id  \
# 0         Chelmsford     61  United States  31414522.0  grid.455372.2
# 1           Torrance     56  United States  23063305.0  grid.281112.9
# 2            Roanoke     41  United States  14837525.0  grid.281080.3
# 3         Huntsville     40  United States  21112784.0  grid.282058.5
# 4    College Station     35  United States  17137067.0  grid.280661.b
# ..               ...    ...            ...         ...            ...
# 517        San Diego      1  United States   1499826.0  grid.505480.c
# 518           Dallas      1  United States    149850.0  grid.505488.4
# 519            Tampa      1  United States    150000.0  grid.509583.2
# 520           Ithaca      1  United States    367305.0    grid.5386.8
# 521            Miami      1  United States    149998.0  grid.65456.34
#
#       latitude                                            linkout   longitude  \
# 0    42.583550                        [http://www.tritonsys.com/]  -71.320570
# 1    33.845474                              [http://www.poc.com/] -118.311950
# 2    37.256560                              [http://lunainc.com/]  -79.942635
# 3    34.726910                            [http://www.cfdrc.com/]  -86.690810
# 4    30.614262                         [http://www.lynntech.com/]  -96.291930
# ..         ...                                                ...         ...
# 517  32.830870                 [http://www.venator-solutions.com] -117.132560
# 518  32.986225                         [http://www.vulintus.com/]  -96.757140
# 519  27.966760  [https://www.shrinershospitalsforchildren.org/...  -82.568830
# 520  42.448510                          [http://www.cornell.edu/]  -76.478620
# 521  25.757440                              [http://www.fiu.edu/]  -80.373280
#
#                                          name     state_name         types  \
# 0              Triton Systems (United States)  Massachusetts     [Company]
# 1                 Physical Optics Corporation     California     [Company]
# 2            Luna Innovations (United States)       Virginia     [Company]
# 3    CFD Research Corporation (United States)        Alabama     [Company]
# 4                    Lynntech (United States)          Texas     [Company]
# ..                                        ...            ...           ...
# 517         Venator Solutions (United States)     California     [Company]
# 518                  Vulintus (United States)          Texas     [Company]
# 519           Shriners Hospitals for Children        Florida  [Healthcare]
# 520                        Cornell University       New York   [Education]
# 521          Florida International University        Florida   [Education]
#
#     acronym
# 0       NaN
# 1       POC
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 517     NaN
# 518     NaN
# 519     SHC
# 520      CU
# 521     FIU
#
# [522 rows x 12 columns]

# %%
px.scatter(dsl_last_results[:100], y="funding", 
               x="name", 
              color="state_name", 
              size="count", 
              height=900,
              title="Funded organizations overview")

# %% [markdown]
# #### Top Countries
#
# Change the last query bit to return `research_org_countries`

# %%
# %%dsldf
#
# search grants
#     where funders.id = "grid.420391.d"
#     and active_year >= 2010
# return research_org_countries limit 1000
# Out:
# Returned Research_org_countries: 6
# Time: 0.55s
#    count  id            name
# 0   1797  US   United States
# 1      2  GB  United Kingdom
# 2      2  MW          Malawi
# 3      2  PE            Peru
# 4      1  FR          France
# 5      1  ZA    South Africa

# %% [markdown]
# #### Who is getting funded outside the US?
#
# Use the filter `research_org_countries.name != "United States"`

# %%
# %%dsldf
#
# search grants
#     where funders.id = "grid.420391.d"
#     and active_year >= 2010
#     and research_org_countries.name != "United States"
# return research_orgs limit 1000
# Out:
# Returned Research_orgs: 3
# Time: 0.71s
#   acronym    city_name  count    country_name             id   latitude  \
# 0    UPCH         Lima      2            Peru  grid.11100.31 -12.023458
# 1   UNIMA        Zomba      1          Malawi  grid.10595.38 -15.389210
# 2    CABI  Wallingford      1  United Kingdom  grid.418543.f  51.590140
#
#                             linkout  longitude                         name  \
# 0  [http://www.upch.edu.pe/portal/] -77.056790  Cayetano Heredia University
# 1            [http://www.unima.mw/]  35.337170         University of Malawi
# 2            [http://www.cabi.org/]  -1.118835            CAB International
#
#          types  state_name
# 0  [Education]         NaN
# 1  [Education]  Nkhotakota
# 2  [Nonprofit]         NaN

# %% [markdown]
# #### How do I see the specific grants information?
#
# Eg if I want to follow up on those non-US grants

# %%
# %%dsldf
#
# search grants
#     where funders.id = "grid.420391.d"
#     and active_year >= 2010
#     and research_org_countries.name != "United States"
# return grants[id+dimensions_url+active_year+funding_org_name+funding_usd+grant_number+title+unnest(research_org_countries)+unnest(research_org_names)+research_orgs] limit 1000
# Out:
# Returned objects: 8 (total grants= 8)
# Time: 0.54s
#                       active_year  \
# 0  [2019, 2020, 2021, 2022, 2023]
# 1              [2016, 2017, 2018]
# 2              [2016, 2017, 2018]
# 3                          [2015]
# 4  [2015, 2016, 2017, 2018, 2019]
# 5              [2015, 2016, 2017]
# 6  [2015, 2016, 2017, 2018, 2019]
# 7              [2013, 2014, 2015]
#
#                                       dimensions_url  \
# 0  https://app.dimensions.ai/details/grant/grant....
# 1  https://app.dimensions.ai/details/grant/grant....
# 2  https://app.dimensions.ai/details/grant/grant....
# 3  https://app.dimensions.ai/details/grant/grant....
# 4  https://app.dimensions.ai/details/grant/grant....
# 5  https://app.dimensions.ai/details/grant/grant....
# 6  https://app.dimensions.ai/details/grant/grant....
# 7  https://app.dimensions.ai/details/grant/grant....
#
#                       funding_org_name  funding_usd   grant_number  \
# 0  United States Department of Defense     760000.0  N681712010002
# 1  United States Department of Defense     300000.0  N681711610002
# 2  United States Department of Defense      94481.0  W9132T1610001
# 3  United States Department of Defense      61342.0  N681711510034
# 4  United States Department of Defense      75105.0  N681711510023
# 5  United States Department of Defense     150000.0  N681711510029
# 6  United States Department of Defense     600000.0  N681711510018
# 7  United States Department of Defense       6000.0  N681711510010
#
#               id research_org_countries.id research_org_countries.name  \
# 0  grant.8684849                        PE                        Peru
# 1  grant.7079883                        MW                      Malawi
# 2  grant.7916652                        GB              United Kingdom
# 3  grant.7079857                        GB              United Kingdom
# 4  grant.7079846                        FR                      France
# 5  grant.7079852                        ZA                South Africa
# 6  grant.7079841                        PE                        Peru
# 7  grant.7079835                        MW                      Malawi
#
#                               research_org_names  \
# 0                    Cayetano Heredia University
# 1                      BAOBAB HEALTH TRUST (BHT)
# 2                              CAB International
# 3                 SIEMAN BIO - MEDICAL SOLUTIONS
# 4                   LA MANT e BUSINESS SOLUTIONS
# 5  Foundation for Professional Development (FPD)
# 6                    Cayetano Heredia University
# 7                           University of Malawi
#
#                                        research_orgs  \
# 0  [{'acronym': 'UPCH', 'city_name': 'Lima', 'cou...
# 1                                                NaN
# 2  [{'acronym': 'CABI', 'city_name': 'Wallingford...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  [{'acronym': 'UPCH', 'city_name': 'Lima', 'cou...
# 7  [{'acronym': 'UNIMA', 'city_name': 'Zomba', 'c...
#
#                                                title
# 0                   HIV/AIDS Prevention Program Peru
# 1                 HIV/AIDS Prevention Program Malawi
# 2  Biological control of Common reed (Phragmites ...
# 3                 HIV/AIDS PREVENTION PROGRAM MALAWI
# 4                HIV/AIDS PREVENTION PROGRAM LESOTHO
# 5           HIV/AIDS Prevention Program South africa
# 6                   HIV/AIDS Prevention Program Peru
# 7                 HIV/AIDS Prevention Program Malawi

# %% [markdown]
# #### Top Researchers

# %%
# %%dsldf
#
# search grants
#     where funders.id = "grid.420391.d"
#     and active_year >= 2010
# return researchers[basics+current_research_org] limit 1000
# Out:
# Returned Researchers: 1000
# Time: 0.97s
#      count current_research_org                first_name                  id  \
# 0       12        grid.281034.c  Girish Srinivas D Girish   ur.01042700104.17
# 1       12        grid.281233.9                   Odile H    ur.0634432601.12
# 2       11        grid.281112.9                   Gregory   ur.01255365415.60
# 3       10        grid.455372.2                       Rod   ur.01153237207.46
# 4        9        grid.455372.2                    Sarena  ur.015111714317.18
# ..     ...                  ...                       ...                 ...
# 995      1                  NaN                     Jason  ur.015323741407.21
# 996      1        grid.422612.1                      Luis  ur.015325455707.17
# 997      1        grid.479364.b                     Terri  ur.015334455543.55
# 998      1                  NaN                      Bran  ur.015334540471.01
# 999      1        grid.261331.4               Vishnu Baba  ur.015345327347.17
#
#              last_name                                      research_orgs  \
# 0             Srinivas                                    [grid.281034.c]
# 1              Clavier  [grid.281233.9, grid.134563.6, grid.63054.34, ...
# 2              Zeltser                                    [grid.281112.9]
# 3                 Jose                                    [grid.455372.2]
# 4               Horava                                    [grid.455372.2]
# ..                 ...                                                ...
# 995               Zhou                                                NaN
# 996         Echevarria                                    [grid.422612.1]
# 997  Dodson-Caldevilla                                    [grid.479364.b]
# 998             Ferren                     [grid.455230.5, grid.21729.3f]
# 999         Sundaresan  [grid.4991.5, grid.438526.e, grid.19006.3e, gr...
#
#                   orcid_id
# 0                      NaN
# 1    [0000-0003-4439-4120]
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ..                     ...
# 995                    NaN
# 996                    NaN
# 997                    NaN
# 998                    NaN
# 999  [0000-0003-4101-9288]
#
# [1000 rows x 7 columns]

# %% [markdown]
# ### 2.4 Getting Publications from a funder ID

# %% [markdown]
# We can use the field `funders`,  which is a direct link from Publications to Funder Organizations (a 'shortcut'), using the funders IDs.

# %%
# %%dsldf
#
# search publications
#     where funders.id = "grid.420391.d"
# return publications[id+title+year+unnest(supporting_grant_ids)]
# Out:
# Returned objects: 29 (total publications= 35990)
# Time: 1.64s
#                 id                                              title  year  \
# 0   pub.1144759864  Analyzing Trajectory Gaps to Find Possible Ren...  2022
# 1   pub.1145403691  Near real-time hurricane rainfall forecasting ...  2022
# 2   pub.1145236788  On the indecomposability of a remarkable new f...  2022
# 3   pub.1144186126  A case study on parallel HDF5 dataset concaten...  2022
# 4   pub.1144186126  A case study on parallel HDF5 dataset concaten...  2022
# 5   pub.1145751220  In vivo MRI evaluation of anterograde manganes...  2022
# 6   pub.1145751220  In vivo MRI evaluation of anterograde manganes...  2022
# 7   pub.1145428082  A contextualized comprehensive action determin...  2022
# 8   pub.1145428082  A contextualized comprehensive action determin...  2022
# 9   pub.1145368233  Surprise is inevitable: How do we train and pr...  2022
# 10  pub.1145126532  Predicting extreme anisotropy and shape variat...  2022
# 11  pub.1145121890  An efficient and statistically accurate Lagran...  2022
# 12  pub.1144903287  Defects and anomalies in powder bed fusion met...  2022
# 13  pub.1144903287  Defects and anomalies in powder bed fusion met...  2022
# 14  pub.1144903287  Defects and anomalies in powder bed fusion met...  2022
# 15  pub.1144903287  Defects and anomalies in powder bed fusion met...  2022
# 16  pub.1144903287  Defects and anomalies in powder bed fusion met...  2022
# 17  pub.1144780947  Properties and fate and transport of persisten...  2022
# 18  pub.1144780947  Properties and fate and transport of persisten...  2022
# 19  pub.1144607634  CNN and Convolutional Autoencoder (CAE) based ...  2022
# 20  pub.1144583807               B n−1-bundles on the flag variety, I  2022
# 21  pub.1144360557  Operability thresholds for thermally damaged E...  2022
# 22  pub.1143930357  Effects of an introduced mustard, Thlaspi arve...  2022
# 23  pub.1141968989  Psychometric Evaluation of the Cybersecurity C...  2022
# 24  pub.1141968989  Psychometric Evaluation of the Cybersecurity C...  2022
# 25  pub.1145756183  Shared Virtual Worlds for Accessible Classroom...  2022
# 26  pub.1145756141  Cross-grade Comparison of Computational Thinki...  2022
# 27  pub.1145665232  Research Techniques Made Simple: Zebrafish Mod...  2022
# 28  pub.1145072612  Tracking spatial regimes in animal communities...  2022
#
#    supporting_grant_ids
# 0                   NaN
# 1         grant.9214518
# 2                   NaN
# 3         grant.7824141
# 4         grant.4320132
# 5         grant.2439145
# 6         grant.7073043
# 7         grant.8326729
# 8         grant.8868775
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12        grant.9621309
# 13        grant.8832450
# 14        grant.7824151
# 15        grant.8541254
# 16        grant.8832885
# 17        grant.9183738
# 18        grant.9183631
# 19        grant.4319029
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23        grant.3144702
# 24        grant.7672080
# 25        grant.7734473
# 26                  NaN
# 27        grant.2682815
# 28                  NaN

# %%
pubs = dsl_last_results

# %% [markdown]
# Now we can retrieve the associated grants.

# %%
temp = pubs.dropna(subset=['supporting_grant_ids'])
grantids = temp['supporting_grant_ids'].to_list()

query = f"""
search grants 
    where id in {json.dumps(grantids)}
return grants[id+title+funders]
"""

linkedgrants = dsl.query(query).as_dataframe()
linkedgrants
# Out:
# Returned Grants: 19 (total = 19)
# Time: 0.95s
#                                               funders             id  \
# 0   [{'acronym': 'NSF MPS', 'city_name': 'Arlingto...  grant.9621309
# 1   [{'acronym': 'NSF OD', 'city_name': 'Arlington...  grant.9214518
# 2   [{'acronym': 'OSD', 'city_name': 'Washington D...  grant.9183631
# 3   [{'acronym': 'NSF ENG', 'city_name': 'Arlingto...  grant.8832885
# 4   [{'acronym': 'NSF ENG', 'city_name': 'Arlingto...  grant.8832450
# 5   [{'acronym': 'NSF MPS', 'city_name': 'Arlingto...  grant.8541254
# 6   [{'acronym': 'NSFC', 'city_name': 'Beijing', '...  grant.8868775
# 7   [{'acronym': 'NSF CISE', 'city_name': 'Arlingt...  grant.7734473
# 8   [{'acronym': 'BES', 'city_name': 'Washington D...  grant.7824151
# 9   [{'acronym': 'ASCR', 'city_name': 'Washington ...  grant.7824141
# 10  [{'acronym': 'NSF EHR', 'city_name': 'Arlingto...  grant.7672080
# 11  [{'acronym': 'OSD', 'city_name': 'Washington D...  grant.9183738
# 12  [{'acronym': 'NSFC', 'city_name': 'Beijing', '...  grant.8326729
# 13  [{'acronym': 'NEI', 'city_name': 'Bethesda', '...  grant.7073043
# 14  [{'acronym': 'NSF SBE', 'city_name': 'Arlingto...  grant.4319029
# 15  [{'acronym': 'ASCR', 'city_name': 'Washington ...  grant.4320132
# 16  [{'acronym': 'NSF EHR', 'city_name': 'Arlingto...  grant.3144702
# 17  [{'acronym': 'NCI', 'city_name': 'Bethesda', '...  grant.2682815
# 18  [{'acronym': 'NEI', 'city_name': 'Bethesda', '...  grant.2439145
#
#                                                 title
# 0   REU Site: Characterization of Materials Using ...
# 1   RII Track-1: Socially Sustainable Solutions fo...
# 2   Development of a Novel PFAS Passive Sampler wi...
# 3   Collaborative Research: Physical Mechanism of ...
# 4   Characterizing the Dynamics of the Laser Metal...
# 5   Fast X-ray Microscopy to Quantify the Nucleati...
# 6   User experience, deep use and out-of-role beha...
# 7   Collaborative Research: NSCI Framework: Softwa...
# 8   Physics-Based Multiscale Additively Manufactur...
# 9   PROTEUS: Machine Learning Driven Resilience fo...
# 10  UMBC CyberCorps Program Renewal and Building R...
# 11  Treatment of Legacy and Emerging Fluoroalkyl C...
# 12  Research on User Multi-level Privacy Concern V...
# 13  Glaucoma Neuroimaging in Humans and Experiment...
# 14  CRISP Type 2: Collaborative Research: Simulati...
# 15  Scalable, In-situ Data Clustering Data Analysi...
# 16  UMBC Cybersecurity Scholarship for Service Pro...
# 17        Translational Cancer Biology Training Grant
# 18                     Core Grant for Vision Research

# %% [markdown]
# ### 2.5 Getting Patents from a funder ID

# %%
# %%dsldf
#
# search patents
#     where funders.id = "grid.420391.d"
# return patents[id+title+year+unnest(associated_grant_ids)]
# Out:
# Returned objects: 29 (total patents= 4800)
# Time: 0.75s
#                id                                              title  year  \
# 0   US-RE43000-E1  Artificial riboswitch for controlling pre-mRNA...  2010
# 1   US-RE41748-E1  Tunable bragg grating and devices employing th...  2009
# 2   US-RE41613-E1   Tunable bragg grating devices employing the same  2006
# 3   US-RE39707-E1                           Camptothecin derivatives  2003
# 4   US-9999684-B2    Methods of treating neurodegenerative disorders  2017
# 5   US-9997883-B1  Apparatuses and methods for reducing risk of b...  2017
# 6   US-9997705-B2  Porous SiOx materials for improvement in SiOx ...  2014
# 7   US-9992048-B2  Systems and methods for detecting unused commu...  2016
# 8   US-9988617-B2  Engineered heme-binding compositions and uses ...  2014
# 9   US-9984143-B2  System and method for resource-adaptive, real-...  2015
# 10  US-9983382-B2  Active aperture partitioning for an imaging sy...  2015
# 11  US-9982304-B2             ARID1A and PPP2R1A mutations in cancer  2011
# 12  US-9982304-B2             ARID1A and PPP2R1A mutations in cancer  2011
# 13  US-9982304-B2             ARID1A and PPP2R1A mutations in cancer  2011
# 14  US-9982304-B2             ARID1A and PPP2R1A mutations in cancer  2011
# 15  US-9982304-B2             ARID1A and PPP2R1A mutations in cancer  2011
# 16  US-9982304-B2             ARID1A and PPP2R1A mutations in cancer  2011
# 17  US-9982304-B2             ARID1A and PPP2R1A mutations in cancer  2011
# 18  US-9982304-B2             ARID1A and PPP2R1A mutations in cancer  2011
# 19  US-9982304-B2             ARID1A and PPP2R1A mutations in cancer  2011
# 20  US-9978002-B2  Object recognizer and detector for two-dimensi...  2015
# 21  US-9977123-B2  Automated track projection bias removal using ...  2015
# 22  US-9975916-B2  Compositions and methods relating to complex n...  2013
# 23  US-9975916-B2  Compositions and methods relating to complex n...  2013
# 24  US-9975576-B2     Drive configurations for skid steered vehicles  2014
# 25  US-9971910-B2  Multi-level security domain separation using s...  2015
# 26  US-9968706-B2  Nerve regeneration employing keratin biomaterials  2015
# 27  US-9968571-B2  Inhibitors and methods of inhibiting bacterial...  2016
# 28  US-9965248-B2  Threshold filtering of compressed domain data ...  2016
#
#    associated_grant_ids
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11        grant.2471197
# 12        grant.2478763
# 13        grant.2634365
# 14        grant.2440141
# 15        grant.2634325
# 16        grant.2469185
# 17        grant.2479421
# 18        grant.2435851
# 19        grant.2477021
# 20                  NaN
# 21                  NaN
# 22        grant.2355378
# 23        grant.3121607
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN

# %% [markdown]
# ## 3. Querying using arbitrary lists of IDs
#
# See also these tutorials
#
# * [Enriching Grants part 2: Adding Publications Information from Dimensions](https://api-lab.dimensions.ai/cookbooks/3-grants/2-grants-enrichment-adding-publications-information.html#)
# * [Working with longs lists of IDs](https://api-lab.dimensions.ai/cookbooks/1-getting-started/6-Working-with-lists.html#5.-How-Long-can-lists-get?)
#
# ### 3.1 From grants to other entities: the links available

# %%
Image(url= "https://docs.dimensions.ai/dsl/_images/data-model-overview-1.png", width=1000)
# Out:
# <img src="https://docs.dimensions.ai/dsl/_images/data-model-overview-1.png" width="1000"/>

# %% [markdown]
# ### 3.2 Example: Patents funders analysis
#
# Example - we want to get an overview of who's funded patents on a specific topic.
#
# **Two steps**
#
# * first, we create a patents dataset using any criteria of choice
# * second, we find associated grants for those patents/grants IDs
#     * since we can have a large number of IDs, we need to pay attention to the API query 'size'

# %%
# %%dslloopdf
#
# search patents
#     for "detection AND explosives"
#     where year >= 2000
#     and associated_grant_ids is not empty
# return patents[id+title+year+unnest(associated_grant_ids)]
# Out:
# Starting iteration with limit=1000 skip=0 ...
# 0-1000 / 1634 (0.81s)
# 1000-1634 / 1634 (1.40s)
# 1634-1634 / 1634 (1.10s)
# ===
# Records extracted: 2592
#      associated_grant_ids                  id  \
# 0           grant.4294962    WO-2020260475-A1
# 1           grant.6944574    WO-2020217046-A1
# 2           grant.3861585    WO-2018138498-A1
# 3           grant.4106834    WO-2018015309-A1
# 4           grant.5073163    WO-2017021424-A1
# ...                   ...                 ...
# 2587        grant.3560299  DE-102016114440-B3
# 2588        grant.2784092    AU-2010308169-B2
# 2589        grant.2778641    AU-2010308169-B2
# 2590        grant.2778641    AU-2010308169-A1
# 2591        grant.2784092    AU-2010308169-A1
#
#                                                   title  year
# 0                                   TRANSFERASE ENZYMES  2020
# 1     SYSTEMS AND METHODS USING ACTIVE FTIR SPECTROS...  2020
# 2                            NON-TARGET SITE RESISTANCE  2018
# 3                                    RAMAN SPECTROSCOPY  2017
# 4                       GAS PHASE FLUORESCENCE ANALYSIS  2016
# ...                                                 ...   ...
# 2587  SERS substrate and method of making a SERS sub...  2016
# 2588                  Intelligent pigments and plastics  2010
# 2589                  Intelligent pigments and plastics  2010
# 2590                  Intelligent pigments and plastics  2010
# 2591                  Intelligent pigments and plastics  2010
#
# [2592 rows x 4 columns]

# %%
patents = dsl_last_results

# %%
# we get grants for those patents, by segmenting the associated_grant_ids list into groups of 300 IDs
# this is because each DSL query can take max ~300 IDs at a time 

from tqdm.notebook import tqdm as progressbar
associated_grant_ids = dsl_last_results['associated_grant_ids'].to_list()


#
# the main API query
#
q = """search grants
          where id in {}
       return grants[id+dimensions_url+researchers+title+active_year+funding_usd+funding_org_name+unnest(funder_countries)+unnest(research_org_countries)+unnest(research_org_names)]"""


#
# let's loop through all IDs in chunks and query Dimensions
#
results = []
for chunk in progressbar(list(chunks_of(list(associated_grant_ids), 300))):
    data = dsl.query_iterative(q.format(json.dumps(chunk)), verbose=True)
    results += data.grants
    time.sleep(1)
    
    

#
# put the data into a dataframe, remove duplicates and save
#
grants = pd.DataFrame().from_dict(results)
print("Grants: ", len(grants))
grants.drop_duplicates(subset='id', inplace=True)
print("Unique Grants: ", len(grants))

#
# preview
#
print("Example:")
grants.head(5)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# Starting iteration with limit=1000 skip=0 ...
# 0-237 / 237 (4.11s)
# 237-237 / 237 (0.67s)
# ===
# Records extracted: 10728
# Starting iteration with limit=1000 skip=0 ...
# 0-203 / 203 (1.13s)
# 203-203 / 203 (0.64s)
# ===
# Records extracted: 215
# Starting iteration with limit=1000 skip=0 ...
# 0-213 / 213 (1.13s)
# 213-213 / 213 (0.57s)
# ===
# Records extracted: 226
# Starting iteration with limit=1000 skip=0 ...
# 0-216 / 216 (1.13s)
# 216-216 / 216 (0.58s)
# ===
# Records extracted: 246
# Starting iteration with limit=1000 skip=0 ...
# 0-203 / 203 (1.08s)
# 203-203 / 203 (0.64s)
# ===
# Records extracted: 219
# Starting iteration with limit=1000 skip=0 ...
# 0-226 / 226 (1.14s)
# 226-226 / 226 (0.64s)
# ===
# Records extracted: 682
# Starting iteration with limit=1000 skip=0 ...
# 0-198 / 198 (0.96s)
# 198-198 / 198 (0.59s)
# ===
# Records extracted: 212
# Starting iteration with limit=1000 skip=0 ...
# 0-238 / 238 (1.22s)
# 238-238 / 238 (0.59s)
# ===
# Records extracted: 265
# Starting iteration with limit=1000 skip=0 ...
# 0-148 / 148 (0.98s)
# 148-148 / 148 (0.53s)
# ===
# Records extracted: 790
# Grants:  13583
# Unique Grants:  905
# Example:
#                              active_year  \
# 0               [2019, 2020, 2021, 2022]
# 1                     [2017, 2018, 2019]
# 13                    [2016, 2017, 2018]
# 16        [2015, 2016, 2017, 2018, 2019]
# 80  [2015, 2016, 2017, 2018, 2019, 2020]
#
#                                        dimensions_url funder_countries.id  \
# 0   https://app.dimensions.ai/details/grant/grant....                  US
# 1   https://app.dimensions.ai/details/grant/grant....                  GB
# 13  https://app.dimensions.ai/details/grant/grant....                  GB
# 16  https://app.dimensions.ai/details/grant/grant....                  GB
# 80  https://app.dimensions.ai/details/grant/grant....                  US
#
#    funder_countries.name                                   funding_org_name  \
# 0          United States                    Office of Basic Energy Sciences
# 1         United Kingdom          Science and Technology Facilities Council
# 13        United Kingdom                           Medical Research Council
# 16        United Kingdom          Science and Technology Facilities Council
# 80         United States  National Institute of Neurological Disorders a...
#
#     funding_usd             id research_org_countries.id  \
# 0     6740681.0  grant.4319520                        US
# 1      385858.0  grant.6944574                        GB
# 13    1013080.0  grant.5073163                        GB
# 16     223964.0  grant.4106834                        GB
# 80    2995818.0  grant.7910079                        US
#
#    research_org_countries.name               research_org_names  \
# 0                United States  University of Wisconsin–Madison
# 1               United Kingdom           Heriot-Watt University
# 13              United Kingdom             Newcastle University
# 16              United Kingdom          University of Leicester
# 80               United States  ASTROCTYE PHARMACEUTICALS, INC.
#
#                                           researchers  \
# 0   [{'first_name': 'Max G', 'id': 'ur.0712201505....
# 1   [{'first_name': 'Derryck T', 'id': 'ur.0100256...
# 13  [{'first_name': 'David Emrys Jeffreys', 'id': ...
# 16  [{'first_name': 'Jonathan Stephen', 'id': 'ur....
# 80  [{'first_name': 'Theodore E', 'id': 'ur.011236...
#
#                                                 title
# 0   Synthesis and Characterization of Composites o...
# 1   Drone-Assisted Fourier-Transform Spectroscopy ...
# 13               Newcastle Confidence in Concept 2015
# 16  Linear Geiger Mode Detector Technology for Tim...
# 80  Preclinical development of AST-004 for astrocy...

# %%
# fix empty values
grants.fillna(0, inplace=True) 

gsubset = grants[grants["funder_countries.name"] == 'United States']

px.scatter(gsubset,
           x="funding_org_name", 
           y="funding_usd", 
           marginal_x="histogram",
           color="funder_countries.name", 
           height=800,
           title="US funding for selected patents dataset")

# %% [markdown]
# ### 3.3 Example: For a given list of DoD awards, how to find out if the awardees have awards from other funders?
#
# **Approach: Three steps**
#
# * first get all grants from DoD
# * second get all awards for those researchers (not just the DoD ones)
# * third, keep only the non-DoD awards

# %%
grants  = dsl.query_iterative(f"""
search grants 
    where funders = "{GRIDID}"
return grants[id+title+grant_number+researchers] 
""").as_dataframe()

grants.head(5)
# Out:
# Starting iteration with limit=1000 skip=0 ...
# 0-1000 / 2436 (1.20s)
# 1000-2000 / 2436 (1.16s)
# 2000-2436 / 2436 (0.86s)
# ===
# Records extracted: 2436
#     grant_number             id  \
# 0  HE12542110005  grant.9785941
# 1  HE12542112007  grant.9881724
# 2  HE12542112004  grant.9881723
# 3  HE12542112003  grant.9881722
# 4  HE12542112002  grant.9881721
#
#                                          researchers  \
# 0  [{'first_name': 'Robert', 'id': 'ur.0163534066...
# 1  [{'first_name': 'Denny', 'id': 'ur.01362142504...
# 2  [{'first_name': 'Helen', 'id': 'ur.01347571321...
# 3  [{'first_name': 'Katie A', 'id': 'ur.012700332...
# 4  [{'first_name': 'Denise', 'id': 'ur.0121027522...
#
#                                                title
# 0  Rethinking Mathematics through the Integration...
# 1  The Knowing and Embracing World Languages (KEW...
# 2                                  Project H.E.L.L.O
# 3          VBCPS Spanish Immersion Expansion Project
# 4                                           PASSPORT

# %%
# ignore grants with no researchers info
grants.dropna(subset=['researchers'], inplace=True)

# get the IDS only
researchers = set()

for index, row in grants.iterrows():
    res = [el['id'] for el in row['researchers']]
    researchers.update(res)

print("Unique researchers: ", len(researchers))
# Out:
# Unique researchers:  1490

# %%
# we get grants for all researchers, by segmenting the researchers list into groups of 300 IDs
# this is because each DSL query can take max ~300 researchers at a time 

from tqdm.notebook import tqdm as progressbar
researcher_ids = researchers

#
# TRIAL RUN: Uncomment this line to use less researchers and speed things up
#
# researcher_ids= researcher_ids[:200]


#
# the main API query
#
q = """search grants
          where researchers in {}
       return grants[id+dimensions_url+researchers+title+active_year+funding_usd+funding_org_name+unnest(funder_countries)+unnest(research_org_countries)+unnest(research_org_names)]"""


#
# let's loop through all researcher IDs in chunks and query Dimensions
#
results = []
for chunk in progressbar(list(chunks_of(list(researcher_ids), 200))):
    data = dsl.query_iterative(q.format(json.dumps(chunk)), verbose=True)
    results += data.grants
    time.sleep(1)

#
# put the data into a dataframe, remove duplicates and save
#
grants = pd.DataFrame().from_dict(results)
print("Grants: ", len(grants))
grants.drop_duplicates(subset='id', inplace=True)
print("Unique Grants: ", len(grants))

#
# preview
#
print("Example:")
grants.head(5)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Starting iteration with limit=1000 skip=0 ...
# 0-1000 / 1286 (1.43s)
# 1000-1286 / 1286 (0.93s)
# 1286-1286 / 1286 (0.64s)
# ===
# Records extracted: 1926
# Starting iteration with limit=1000 skip=0 ...
# 0-1000 / 1690 (1.47s)
# 1000-1690 / 1690 (1.13s)
# 1690-1690 / 1690 (0.59s)
# ===
# Records extracted: 2670
# Starting iteration with limit=1000 skip=0 ...
# 0-1000 / 1608 (1.00s)
# 1000-1608 / 1608 (1.20s)
# 1608-1608 / 1608 (0.58s)
# ===
# Records extracted: 2405
# Starting iteration with limit=1000 skip=0 ...
# 0-1000 / 1695 (1.65s)
# 1000-1695 / 1695 (1.24s)
# 1695-1695 / 1695 (0.62s)
# ===
# Records extracted: 2923
# Starting iteration with limit=1000 skip=0 ...
# 0-1000 / 1883 (1.04s)
# 1000-1883 / 1883 (1.50s)
# 1883-1883 / 1883 (0.58s)
# ===
# Records extracted: 2716
# Starting iteration with limit=1000 skip=0 ...
# 0-1000 / 1542 (1.27s)
# 1000-1542 / 1542 (0.83s)
# 1542-1542 / 1542 (0.57s)
# ===
# Records extracted: 2320
# Starting iteration with limit=1000 skip=0 ...
# 0-1000 / 1914 (1.43s)
# 1000-1914 / 1914 (1.24s)
# 1914-1914 / 1914 (0.64s)
# ===
# Records extracted: 3252
# Starting iteration with limit=1000 skip=0 ...
# 0-859 / 859 (1.26s)
# 859-859 / 859 (2.38s)
# ===
# Records extracted: 1270
# Grants:  19482
# Unique Grants:  12464
# Example:
#                             active_year  \
# 0  [2021, 2022, 2023, 2024, 2025, 2026]
# 1  [2021, 2022, 2023, 2024, 2025, 2026]
# 2  [2021, 2022, 2023, 2024, 2025, 2026]
# 3                          [2021, 2022]
# 4                          [2021, 2022]
#
#                                       dimensions_url funder_countries.id  \
# 0  https://app.dimensions.ai/details/grant/grant....                  US
# 1  https://app.dimensions.ai/details/grant/grant....                  US
# 2  https://app.dimensions.ai/details/grant/grant....                  US
# 3  https://app.dimensions.ai/details/grant/grant....                  US
# 4  https://app.dimensions.ai/details/grant/grant....                  US
#
#   funder_countries.name                                   funding_org_name  \
# 0         United States                United States Department of Defense
# 1         United States                United States Department of Defense
# 2         United States                United States Department of Defense
# 3         United States  National Institute of Neurological Disorders a...
# 4         United States           National Human Genome Research Institute
#
#    funding_usd             id research_org_countries.id  \
# 0    1000000.0  grant.9881720                        US
# 1    2342517.0  grant.9843160                        US
# 2     750000.0  grant.9785949                        US
# 3     256364.0  grant.9847720                        US
# 4     399999.0  grant.9847712                        US
#
#   research_org_countries.name                          research_org_names  \
# 0               United States  Monterey Peninsula Unified School District
# 1               United States            Coronado Unified School District
# 2               United States                        Belle Chasse Academy
# 3               United States                    Vulintus (United States)
# 4               United States      Electronic BioSciences (United States)
#
#                                          researchers  \
# 0  [{'first_name': 'Cresta', 'id': 'ur.0125641042...
# 1  [{'first_name': 'Stacy', 'id': 'ur.01102232365...
# 2  [{'first_name': 'Lauran', 'id': 'ur.0150265610...
# 3  [{'first_name': 'Andrew Michael', 'id': 'ur.01...
# 4  [{'first_name': 'Eric Nathan', 'id': 'ur.01136...
#
#                                                title
# 0                           Computer Science for All
# 1                                World Language Plus
# 2                         Belle Chasse Academy Grant
# 3  SensiTrak: Automated Assessment of Forelimb Se...
# 4  Long-lived Platform Development for Exonucleas...

# %%
# fix empty values
grants.fillna(0, inplace=True) 
# add aggregated counts
grants['country_count'] = grants.groupby('funder_countries.name')['id'].transform('count')
grants['country_funding'] = grants.groupby('funder_countries.name')['funding_usd'].transform('sum')

gsubset = grants[['funder_countries.name', 'country_count']]
px.choropleth(gsubset.drop_duplicates(), 
                  locations="funder_countries.name",
                  locationmode="country names",
                  color="country_count", 
                  hover_name="funder_countries.name",
                  color_continuous_scale=px.colors.sequential.Plasma,
                  title="Researchers' funding: number of grants by funder countries")

# %%
gsubset = grants[grants["funder_countries.name"] != 'United States']

px.scatter(gsubset,
           y="funding_org_name", 
           x="research_org_names", 
           marginal_x="histogram",
           color="funder_countries.name", 
           height=800,
           title="Researchers' funding: funders from outside the US")

# %% [markdown]
# #### To find out who are the researchers

# %%
# eg for Japan

COUNTRY = "Japan"

focus_set = grants[grants["funder_countries.name"] == COUNTRY]['researchers'].to_list()

for res in focus_set[0]:
    if res['id'] in researcher_ids:
        print(res['first_name'], res['last_name'], "\n", dimensions_url(res['id'], 'researchers'))
# Out:
# Behnood Gholami
#  https://app.dimensions.ai/discover/publication?and_facet_researcher=ur.01060604140.32

# %% [markdown]
# ## More tutorials
#
# * Doing this at scale: see the [Working with lists tutorial](https://api-lab.dimensions.ai/cookbooks/1-getting-started/6-Working-with-lists.html) that shows how to deal with list of researchers / grants of any size, using pagination and 'chunking' methods
# * Makings the analysis more specific by using the [investigators details data structure](https://docs.dimensions.ai/dsl/datasource-grants.html#grants-investigators-long-desc) in the API grants model
# * Going from grants to [Related publications](https://api-lab.dimensions.ai/cookbooks/3-grants/2-grants-enrichment-adding-publications-information.html)
# * Going from grants to [Related Patents and Clinical Trials](https://api-lab.dimensions.ai/cookbooks/3-grants/3-grants-enrichment-adding-patents-cltrials-information.html)
