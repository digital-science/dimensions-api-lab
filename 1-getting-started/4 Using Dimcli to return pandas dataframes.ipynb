# %% [markdown]
# <a href="https://colab.research.google.com/github/digital-science/dimensions-api-lab/blob/master/1-getting-started/4%20Using%20Dimcli%20to%20return%20pandas%20dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open Dimensions API Lab In Google Colab"/></a>

# %% [markdown]
# # Dimcli: returning DataFrames
#
# DimCli includes a few utilities that make it easier to transform Dimensions JSON data into Pandas [dataframe objects](https://pandas.pydata.org/pandas-docs/stable/getting_started/dsintro.html#dataframe).
#
# Dataframes are then easy to sort, analyse, export as CSV and use within visualisation softwares.
#
# >  [pandas](https://pandas.pydata.org/pandas-docs/stable/) is a popular software library written for the Python programming language for data manipulation and analysis.

# %%
import pandas
import dimcli
from dimcli.shortcuts import dslquery
dimcli.login()
# Out:
# DimCli v0.5.4 - Succesfully connected to <https://app.dimensions.ai> (method: dsl.ini file)

# %% [markdown]
# ## 1. Getting started: the `as_dataframe` method
#
# This utility method allows to quickly turn any query results into a dataframe.

# %%
# we'll reuse this query later on 
query = """search publications for "graphene" where year=[2013:2019] return publications sort by times_cited limit 1000"""
res = dslquery(query)
# Out:
# Returned Publications: 1000 (total = 365807)

# %%
df = res.as_dataframe()
df.head(10)
# Out:
#                                  author_affiliations              id issue  \
# 0  [[{'first_name': 'Manish', 'last_name': 'Chhow...  pub.1050119463     4
# 1  [[{'first_name': 'A. K.', 'last_name': 'Geim',...  pub.1024857999  7459
# 2  [[{'first_name': 'Huanping', 'last_name': 'Zho...  pub.1004394295  6196
# 3  [[{'first_name': 'Likai', 'last_name': 'Li', '...  pub.1032956475     5
# 4  [[{'first_name': 'C.', 'last_name': 'Patrignan...  pub.1059158429    10
# 5  [[{'first_name': 'John B.', 'last_name': 'Good...  pub.1019126274     4
# 6  [[{'first_name': 'Michael F. L.', 'last_name':...  pub.1007405937  6119
# 7  [[{'first_name': 'Andrea C.', 'last_name': 'Fe...  pub.1015305822     4
# 8  [[{'first_name': 'Han', 'last_name': 'Liu', 'o...  pub.1009826879     4
# 9  [[{'first_name': 'Martin A.', 'last_name': 'Gr...  pub.1045181228     7
#
#      journal.id                             journal.title    pages  \
# 0  jour.1041224                          Nature Chemistry      263
# 1  jour.1018957                                    Nature      419
# 2  jour.1346339                                   Science  542-546
# 3  jour.1037429                     Nature Nanotechnology  372-377
# 4  jour.1327822                         Chinese Physics C   100001
# 5  jour.1081898  Journal of the American Chemical Society  1167-76
# 6  jour.1346339                                   Science  535-539
# 7  jour.1037429                     Nature Nanotechnology      235
# 8  jour.1038917                                  ACS Nano  4033-41
# 9  jour.1037430                          Nature Photonics  506-514
#
#                                                title     type volume  year
# 0  The chemistry of two-dimensional layered trans...  article      5  2013
# 1                     Van der Waals heterostructures  article    499  2013
# 2  Interface engineering of highly efficient pero...  article    345  2014
# 3          Black phosphorus field-effect transistors  article      9  2014
# 4                         Review of Particle Physics  article     40  2016
# 5    The Li-ion rechargeable battery: a perspective.  article    135  2013
# 6  Carbon Nanotubes: Present and Future Commercia...  article    339  2013
# 7  Raman spectroscopy as a versatile tool for stu...  article      8  2013
# 8  Phosphorene: an unexplored 2D semiconductor wi...  article      8  2014
# 9            The emergence of perovskite solar cells  article      8  2014

# %% [markdown]
# Pandas dataframes offer a myriad of utilities for inspecting data. Check out the [official docs](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html) or google a [pandas tutorial](https://www.google.com/search?q=pandas+tutorial) to lean more about it.

# %%
# the 'describe' method returns basic statistic for all columns of a dataframe
df.describe(include='all')
# Out:
#                                       author_affiliations              id  \
# count                                                 998            1000
# unique                                                997            1000
# top     [[{'first_name': 'Jingjing', 'last_name': 'Dua...  pub.1045356440
# freq                                                    2               1
# mean                                                  NaN             NaN
# std                                                   NaN             NaN
# min                                                   NaN             NaN
# 25%                                                   NaN             NaN
# 50%                                                   NaN             NaN
# 75%                                                   NaN             NaN
# max                                                   NaN             NaN
#
#        issue    journal.id             journal.title    pages  \
# count    934           997                       997      996
# unique   135           143                       143      987
# top        1  jour.1015766  Chemical Society Reviews  421-425
# freq     174           106                       106        2
# mean     NaN           NaN                       NaN      NaN
# std      NaN           NaN                       NaN      NaN
# min      NaN           NaN                       NaN      NaN
# 25%      NaN           NaN                       NaN      NaN
# 50%      NaN           NaN                       NaN      NaN
# 75%      NaN           NaN                       NaN      NaN
# max      NaN           NaN                       NaN      NaN
#
#                                                     title     type volume  \
# count                                                1000     1000    997
# unique                                               1000        4    166
# top     Layered SnS2‐Reduced Graphene Oxide Composite ...  article      7
# freq                                                    1      997     67
# mean                                                  NaN      NaN    NaN
# std                                                   NaN      NaN    NaN
# min                                                   NaN      NaN    NaN
# 25%                                                   NaN      NaN    NaN
# 50%                                                   NaN      NaN    NaN
# 75%                                                   NaN      NaN    NaN
# max                                                   NaN      NaN    NaN
#
#                year
# count   1000.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean    2014.114000
# std        1.103731
# min     2013.000000
# 25%     2013.000000
# 50%     2014.000000
# 75%     2015.000000
# max     2018.000000

# %%
# the 'value_counts' method returns the distribution of a specific field eg publication [years]
df['year'].value_counts()
# Out:
# 2013    362
# 2014    316
# 2015    206
# 2016     82
# 2017     30
# 2018      4
# Name: year, dtype: int64

# %%
# eg distribution of publication [type]
df['type'].value_counts()
# Out:
# article      997
# monograph      1
# book           1
# chapter        1
# Name: type, dtype: int64

# %% [markdown]
# ## 2. Helper Methods for 'Publications' queries

# %% [markdown]
# ##  Publications authors: `as_dataframe_authors`
#
# Publications authors are usually returned by the Dimensions API inside a nested JSON object in the `authors_affiliations` sub-key.
#
# > Note: the order of authors in the JSON is consistent with the ordering of authors in the original publication
#
# This methods allows to quickly extract that data and return a dataframe with **one row per author**.

# %%
authors = res.as_dataframe_authors()
authors.head()
# Out:
#                                         affiliations current_organization_id  \
# 0  [{'id': 'grid.430387.b', 'name': 'Rutgers, The...           grid.430387.b
# 1  [{'id': 'grid.42687.3f', 'name': 'Ulsan Nation...           grid.42687.3f
# 2  [{'id': 'grid.4280.e', 'name': 'National Unive...             grid.4280.e
# 3  [{'id': 'grid.482254.d', 'name': 'Institute of...           grid.45672.32
# 4  [{'id': 'grid.4280.e', 'name': 'National Unive...             grid.4280.e
#
#   first_name  last_name                    orcid      researcher_id  \
# 0     Manish  Chhowalla                            ur.0633062306.03
# 1  Hyeon Suk       Shin                           ur.07617630407.83
# 2       Goki        Eda                           ur.01150450507.27
# 3  Lain-Jong         Li  ['0000-0002-4059-7783']  ur.01313340113.13
# 4  Kian Ping        Loh  ['0000-0002-1491-743X']   ur.0752174033.73
#
#            pub_id
# 0  pub.1050119463
# 1  pub.1050119463
# 2  pub.1050119463
# 3  pub.1050119463
# 4  pub.1050119463

# %% [markdown]
# Using the authors dataframe, we can easily get the top ten values for `current_organization_id`.

# %%
authors['current_organization_id'].value_counts()[:10]
# Out:
#                  173
# grid.59025.3b    153
# grid.168010.e    150
# grid.12527.33     93
# grid.5379.8       86
# grid.59053.3a     86
# grid.5333.6       78
# grid.116068.8     71
# grid.19006.3e     71
# grid.13402.34     68
# Name: current_organization_id, dtype: int64

# %% [markdown]
# > Explanation: the most frequent value turns to be grid.59025.3b ie [Nanyang Technological University in Singapore](https://www.grid.ac/institutes/grid.59025.3b). The second result is empty, meaning that for those authors Dimensions has no info about `current_organization_id`.

# %% [markdown]
# ## Publications affiliations: `as_dataframe_authors_affiliations`
#
# As you can see from the results of the previous section, the `affiliations` of each author is yet another nested JSON object.
#
# > Note: the order of affiliations in the JSON is consistent with the affiliations order in the original publication
#
# The `as_dataframe_authors_affiliations` method allows to quickly extract that affiliations data and return a dataframe with **one row per affiliation**.
#
# This can be useful e.g. if one wants to count research organizations at *the time of writing* (as opposed to `current_organization_id`, which is the *most recent organization* of a researcher).

# %%
affiliations = res.as_dataframe_authors_affiliations()
affiliations.head()
# Out:
#         aff_city  aff_city_id    aff_country aff_country_code         aff_id  \
# 0  New Brunswick    5101717.0  United States               US  grid.430387.b
# 1          Ulsan    1833747.0    South Korea               KR  grid.42687.3f
# 2      Singapore    1880252.0      Singapore               SG    grid.4280.e
# 3         Taipei    1668341.0         Taiwan               TW  grid.482254.d
# 4      Singapore    1880252.0      Singapore               SG    grid.4280.e
#
#                                             aff_name   aff_state  \
# 0        Rutgers, The State University of New Jersey  New Jersey
# 1  Ulsan National Institute of Science and Techno...        None
# 2                   National University of Singapore        None
# 3  Institute of Atomic and Molecular Sciences, Ac...        None
# 4                   National University of Singapore        None
#
#   aff_state_code          pub_id      researcher_id first_name  last_name
# 0          US-NJ  pub.1050119463   ur.0633062306.03     Manish  Chhowalla
# 1           None  pub.1050119463  ur.07617630407.83  Hyeon Suk       Shin
# 2           None  pub.1050119463  ur.01150450507.27       Goki        Eda
# 3           None  pub.1050119463  ur.01313340113.13  Lain-Jong         Li
# 4           None  pub.1050119463   ur.0752174033.73  Kian Ping        Loh

# %%
affiliations.describe(include="all")
# Out:
#        aff_city   aff_city_id    aff_country aff_country_code         aff_id  \
# count      6413  6.407000e+03           6413             6413           6413
# unique      428           NaN             50               50            718
# top     Beijing           NaN  United States               US  grid.59025.3b
# freq        631           NaN           1949             1949            229
# mean        NaN  3.039684e+06            NaN              NaN            NaN
# std         NaN  1.553733e+06            NaN              NaN            NaN
# min         NaN  6.609300e+04            NaN              NaN            NaN
# 25%         NaN  1.816670e+06            NaN              NaN            NaN
# 50%         NaN  2.174003e+06            NaN              NaN            NaN
# 75%         NaN  4.722625e+06            NaN              NaN            NaN
# max         NaN  8.469294e+06            NaN              NaN            NaN
#
#                                 aff_name   aff_state aff_state_code  \
# count                               7187        2202           2202
# unique                               998          51             51
# top     Nanyang Technological University  California          US-CA
# freq                                 229         548            548
# mean                                 NaN         NaN            NaN
# std                                  NaN         NaN            NaN
# min                                  NaN         NaN            NaN
# 25%                                  NaN         NaN            NaN
# 50%                                  NaN         NaN            NaN
# 75%                                  NaN         NaN            NaN
# max                                  NaN         NaN            NaN
#
#                 pub_id researcher_id first_name last_name
# count             7187          7187       7187      7187
# unique             985          4298       3450      1985
# top     pub.1019661721                       Yi      Wang
# freq               105           140         63       300
# mean               NaN           NaN        NaN       NaN
# std                NaN           NaN        NaN       NaN
# min                NaN           NaN        NaN       NaN
# 25%                NaN           NaN        NaN       NaN
# 50%                NaN           NaN        NaN       NaN
# 75%                NaN           NaN        NaN       NaN
# max                NaN           NaN        NaN       NaN

# %% [markdown]
# Let's get the top ten values for `aff_id`.

# %%
affiliations['aff_id'].value_counts()[:10]
# Out:
# grid.59025.3b    229
# grid.168010.e    202
# grid.12527.33    111
# grid.21729.3f    106
# grid.19006.3e     98
# grid.5379.8       90
# grid.9227.e       84
# grid.116068.8     83
# grid.5333.6       82
# grid.59053.3a     82
# Name: aff_id, dtype: int64

# %% [markdown]
# > Explanation: the most frequent value is still [grid.59025.3b](https://www.grid.ac/institutes/grid.59025.3b), meaning that most authors' current organization is the same organization of when they published these articles.

# %% [markdown]
# Another example: we can now easily analyze the data by country too.

# %%
affiliations['aff_country'].value_counts()[:10]
# Out:
# United States     1949
# China             1914
# Singapore          328
# South Korea        313
# United Kingdom     261
# Germany            201
# Japan              168
# Australia          157
# Switzerland        122
# Taiwan             101
# Name: aff_country, dtype: int64

# %% [markdown]
# > Explanation: the vast majority of authors in this dataset are from the United States, closely followed by China.

# %% [markdown]
# ## 2. Helper Methods for 'Grants' queries

# %% [markdown]
# ##  Grants funders: `as_dataframe_funders`
#
# Grant funders authors are usually returned by the Dimensions API inside a nested JSON object in the `funders` sub-key.
#
# This methods allows to quickly extract that data and return a dataframe with **one row per funder**.

# %%
# get a sample list of grants
query = """search grants for "malaria" return grants limit 1000"""
res = dslquery(query)
# Out:
# Returned Grants: 1000 (total = 9280)

# %%
res.as_dataframe_funders().head(10)
# Out:
#    acronym    country_name             id  \
# 0       WT  United Kingdom  grid.52788.30
# 1     CIHR          Canada  grid.248883.d
# 2  NSF SBE   United States  grid.457916.8
# 3       WT  United Kingdom  grid.52788.30
# 4     CIHR          Canada  grid.248883.d
# 5     CIHR          Canada  grid.248883.d
# 6  NSF MPS   United States  grid.457875.c
# 7    BBSRC  United Kingdom  grid.418100.c
# 8      AMS  United Kingdom  grid.420331.7
# 9    MSFHR          Canada  grid.453291.8
#
#                                                 name       grant_id  \
# 0                                     Wellcome Trust  grant.8103743
# 1             Canadian Institutes of Health Research  grant.8527034
# 2  Directorate for Social, Behavioral & Economic ...  grant.7923573
# 3                                     Wellcome Trust  grant.8103357
# 4             Canadian Institutes of Health Research  grant.8482815
# 5             Canadian Institutes of Health Research  grant.8527284
# 6   Directorate for Mathematical & Physical Sciences  grant.8522823
# 7  Biotechnology and Biological Sciences Research...  grant.8483462
# 8                        Academy of Medical Sciences  grant.7921305
# 9       Michael Smith Foundation for Health Research  grant.7823904
#
#                                          grant_title grant_start_date  \
# 0  The Chemical Empire: A New History of Syntheti...       2019-10-01
# 1  Mechanisms of Leishmania dissemination and tra...       2019-10-01
# 2  CAREER: A Case Study of Malaria Elimination Ef...       2019-09-01
# 3  Quantifying the influence of wind on mosquito ...       2019-09-01
# 4  Investigating the Host-Pathogen Interactions o...       2019-09-01
# 5  Investigation of antibody-mediated immune mech...       2019-09-01
# 6  Membrane and Monolith Enzyme Reactors for Prot...       2019-08-01
# 7  Defining mechani1sms of CD8+ T-cell mediated i...       2019-07-31
# 8  Analysis of innate immune responses following ...       2019-07-15
# 9  Phosphoinositide kinases: molecular determinan...       2019-07-01
#
#   grant_end_date
# 0     2023-09-30
# 1     2024-09-30
# 2     2024-08-31
# 3     2020-08-31
# 4     2020-08-31
# 5     2020-08-31
# 6     2022-07-31
# 7     2022-07-30
# 8     2021-07-14
# 9     2024-06-30

# %% [markdown]
# ##  Grants investigators: `as_dataframe_investigators`
#
# Grant investigators are usually returned by the Dimensions API inside a nested JSON object in the `investigator_details` sub-key.
#
# This methods allows to quickly extract that data and return a dataframe with **one row per investigator**.
#
# > NOTE: `investigator_details` are not returned by default in a grants query hence one must specify this in the query results

# %%
# get a sample list of grants
query = """search grants for "malaria" return grants[basics+investigator_details] limit 1000"""
res = dslquery(query)
# Out:
# Returned Grants: 1000 (total = 9280)

# %%
res.as_dataframe_investigators().head(10)
# Out:
#                                         affiliations   first_name  \
# 0  [{'city': 'York', 'state_code': None, 'country...       Sabine
# 1                                                NaN       Nathan
# 2  [{'state_code': 'US-OR', 'id': 'grid.170202.6'...      Melissa
# 3  [{'city': 'Liverpool', 'state_code': None, 'co...  Christopher
# 4                                                NaN       Nicola
# 5                                                NaN    Madeleine
# 6  [{'state_code': 'US-IN', 'id': 'grid.131063.6'...       Merlin
# 7  [{'city': None, 'state_code': None, 'name': 'U...          Tim
# 8  [{'city': None, 'state_code': None, 'name': 'U...         Musa
# 9  [{'state': None, 'state_code': None, 'city': N...         Ruth
#
#                    id  last_name middle_name   role       grant_id  \
# 0   ur.07547552115.05     Clarke       Marie     PI  grant.8103743
# 1                None     Peters                 PI  grant.8527034
# 2  ur.011503504405.93   Graboyes        None     PI  grant.7923573
# 3  ur.010302660415.98      Jones        Mark     PI  grant.8103357
# 4                None       Case                 PI  grant.8482815
# 5                None      Wiebe      Claire     PI  grant.8527284
# 6                None   Bruening        None     PI  grant.8522823
# 7                None  Connelley                 PI  grant.8483462
# 8                None     Hassan       Abdul  Co-PI  grant.8483462
# 9  ur.010655625375.45      Payne                 PI  grant.7921305
#
#                                          grant_title grant_start_date  \
# 0  The Chemical Empire: A New History of Syntheti...       2019-10-01
# 1  Mechanisms of Leishmania dissemination and tra...       2019-10-01
# 2  CAREER: A Case Study of Malaria Elimination Ef...       2019-09-01
# 3  Quantifying the influence of wind on mosquito ...       2019-09-01
# 4  Investigating the Host-Pathogen Interactions o...       2019-09-01
# 5  Investigation of antibody-mediated immune mech...       2019-09-01
# 6  Membrane and Monolith Enzyme Reactors for Prot...       2019-08-01
# 7  Defining mechani1sms of CD8+ T-cell mediated i...       2019-07-31
# 8  Defining mechani1sms of CD8+ T-cell mediated i...       2019-07-31
# 9  Analysis of innate immune responses following ...       2019-07-15
#
#   grant_end_date
# 0     2023-09-30
# 1     2024-09-30
# 2     2024-08-31
# 3     2020-08-31
# 4     2020-08-31
# 5     2020-08-31
# 6     2022-07-31
# 7     2022-07-30
# 8     2022-07-30
# 9     2021-07-14

# %% [markdown]
# ## Conclusions
#
# Moving Dimensions API results to pandas dataframes **makes it easier** to **analyze the data** and **answer research questions**.
#
# Note: the examples above only scratch the surface of what can be done with pandas!

# %% [markdown]
# ---
# # Want to learn more?
#
# Check out the [Dimensions API Lab](https://digital-science.github.io/dimensions-api-lab/) website, which contains many tutorials and reusable Jupyter notebooks for scholarly data analytics.
