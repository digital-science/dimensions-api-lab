# %% [markdown]
# <a href="https://colab.research.google.com/github/digital-science/dimensions-api-lab" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open Dimensions API Lab In Google Colab"/></a>

# %% [markdown]
# # Part 4: Institutions
#
# ## Install Dimensions Library and login

# %%
try:
  from google.colab import files
  # %load_ext google.colab.data_table
  COLAB_ENV = True
  # !pip install dimcli plotly_express  -U
  # !mkdir data # to save temp data 
except:
  COLAB_ENV = False


# common libraries
import pandas as pd
from pandas.io.json import json_normalize
import time
from tqdm import tqdm_notebook as tqdm
import plotly_express as px
from getpass import getpass
# FINALLY..
import dimcli
from dimcli.shortcuts import *

# set up for exports
if not COLAB_ENV:
  from plotly.offline import init_notebook_mode # needed for exports 
  init_notebook_mode(connected=True)


##
# LOG IN 
##

USERNAME = "m.pasin@digital-science.com"  #@param {type: "string"}

if not USERNAME:
  print("====\nERROR: Please enter a valid Dimensions API username")
else:
  password = getpass('====\nEnter password here')
  print('=> username is', USERNAME)
  print('=> password is', "*" * len(password))
  dimcli.login(USERNAME, password)
  dsl = dimcli.Dsl()

# %% [markdown]
# # Institutions Contributing to a Journal

# %% [markdown]
# From our original publications dataset, we now want to look at institutions i.e.
#
# * getting the full list of institutions (also ones without a GRID, for subsequent analysis) linked to the journal
# * publications count
# * authors count
#
# Let's reload the affiliations data from Part-1 of the tutorial.

# %%
affiliations = pd.read_csv("data/1.publications_authors_affiliations.csv")
affiliations
# Out:
#              aff_city  aff_city_id  ...      first_name     last_name
# 0            Besançon    3033123.0  ...          Pierre        Vabres
# 1               Dijon    3021372.0  ...          Pierre        Vabres
# 2            Besançon    3033123.0  ...          Arthur        Sorlin
# 3               Dijon    3021372.0  ...          Arthur        Sorlin
# 4              Ithaca    5122432.0  ...    Stanislav S.  Kholmanskikh
# 5              Amiens    3037854.0  ...       Bénédicte        Demeer
# 6               Dijon    3021372.0  ...          Judith       St-Onge
# 7            Besançon    3033123.0  ...          Judith       St-Onge
# 8            Montreal    6077243.0  ...          Judith       St-Onge
# 9               Dijon    3021372.0  ...          Yannis      Duffourd
# 10           Besançon    3033123.0  ...          Yannis      Duffourd
# 11              Dijon    3021372.0  ...            Paul        Kuentz
# 12           Besançon    3033123.0  ...            Paul        Kuentz
# 13           Besançon    3033123.0  ...            Paul        Kuentz
# 14           Besançon    3033123.0  ...     Jean-Benoît       Courcet
# 15              Dijon    3021372.0  ...     Jean-Benoît       Courcet
# 16           Besançon    3033123.0  ...        Virginie     Carmignac
# 17              Dijon    3021372.0  ...        Virginie     Carmignac
# 18              Dijon    3021372.0  ...      Philippine        Garret
# 19           Besançon    3033123.0  ...      Philippine        Garret
# 20        Montpellier    2992166.0  ...          Didier        Bessis
# 21              Lille    2998324.0  ...           Odile         Boute
# 22              Dijon    3021372.0  ...           Alain          Bron
# 23        Montpellier    2992166.0  ...       Guillaume       Captier
# 24                NaN          NaN  ...          Esther         Carmi
# 25             Amiens    3037854.0  ...         Bernard   Devauchelle
# 26        Montpellier    2992166.0  ...           David     Geneviève
# 27             Amiens    3037854.0  ...       Catherine  Gondry-Jouet
# 28               Lyon    2996944.0  ...         Laurent       Guibaud
# 29              Dijon    3021372.0  ...          Arnaud         Lafon
# ...               ...          ...  ...             ...           ...
# 49445          Dallas    4684888.0  ...         Haley M          Hill
# 49446          Nutley    5102076.0  ...          Jeremy       Stinson
# 49447          Nutley    5102076.0  ...  Celina Sanchez        Rivers
# 49448          Nutley    5102076.0  ...   Vasantharajan   Janakiraman
# 49449          Nutley    5102076.0  ...           Weiru          Wang
# 49450          Dallas    4684888.0  ...          Lisa N         Kinch
# 49451     Chevy Chase    4351335.0  ...          Lisa N         Kinch
# 49452          Dallas    4684888.0  ...          Nick V       Grishin
# 49453     Chevy Chase    4351335.0  ...          Nick V       Grishin
# 49454          Nutley    5102076.0  ...         Peter M       Haverty
# 49455          Nutley    5102076.0  ...         Bernard          Chow
# 49456          Nutley    5102076.0  ...        Julian S       Gehring
# 49457          Nutley    5102076.0  ...            Jens        Reeder
# 49458          Nutley    5102076.0  ...        Gregoire           Pau
# 49459          Nutley    5102076.0  ...        Thomas D            Wu
# 49460          Dallas    4684888.0  ...          Vitaly      Margulis
# 49461          Dallas    4684888.0  ...            Yair         Lotan
# 49462          Dallas    4684888.0  ...          Arthur    Sagalowsky
# 49463          Dallas    4684888.0  ...            Ivan       Pedrosa
# 49464          Nutley    5102076.0  ...      Frederic J    de Sauvage
# 49465          Dallas    4684888.0  ...           James    Brugarolas
# 49466          Nutley    5102076.0  ...       Somasekar     Seshagiri
# 49467      Copenhagen    2618425.0  ...    Rasmus Lykke        Marvig
# 49468  Kongens Lyngby    2618468.0  ...    Rasmus Lykke        Marvig
# 49469  Kongens Lyngby    2618468.0  ...       Lea Mette        Sommer
# 49470  Kongens Lyngby    2618468.0  ...           Søren         Molin
# 49471      Copenhagen    2618425.0  ...     Helle Krogh      Johansen
# 49472  Kongens Lyngby    2618468.0  ...     Helle Krogh      Johansen
# 49473         Chicago    4887398.0  ...       Sebastian          Pott
# 49474         Chicago    4887398.0  ...         Jason D          Lieb
#
# [49475 rows x 12 columns]

# %% [markdown]
# ## Some stats about affiliations
#
# * count how many affiliations statements in total
# * count how many affiliations have a GRID ID
# * count how many unique GRID IDs we have in total

# %%
#
# segment the affiliations dataset
affiliations = affiliations.fillna('') 
gridaffiliations = affiliations.query("aff_id != ''")
non_gridaffiliations = affiliations.query("aff_id == ''")
#
# save
gridaffiliations.to_csv("data/4.Affiliations-with-grid.csv", index=False)
non_gridaffiliations.to_csv("data/4.Affiliations-without-grid.csv", index=False)

# %%
# build a summary barchart

df = pd.DataFrame({
    'measure' : ['Affiliations in total (non unique)', 'Affiliations with a GRID ID', 'Affiliations with a GRID ID (unique)'],
    'count' : [len(affiliations), len(gridaffiliations), gridaffiliations['aff_id'].nunique()],
})
px.bar(df, x="measure", y="count", title=f"Affiliations stats")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="649c97a4-260d-4969-9e86-958126e62b38" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("649c97a4-260d-4969-9e86-958126e62b38")) {
#                     Plotly.newPlot(
#                         '649c97a4-260d-4969-9e86-958126e62b38',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "measure=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Affiliations in total (non unique)", "Affiliations with a GRID ID", "Affiliations with a GRID ID (unique)"], "xaxis": "x", "y": [49475, 43865, 2487], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 600, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{" ...

# %% [markdown]
# ## Enriching the unique affiliations (GRIDs list) with pubs count and authors count

# %% [markdown]
# We want a table with the following columns
#
# * grid ID
# * city
# * country
# * country code
# * name
# * tot_pubs
# * tot_affiliations
#
# NOTE: tot_affiliations is a list of non unique authors

# %%
gridaffiliations.head(5)
# Out:
#    aff_city  aff_city_id  ...    first_name     last_name
# 0  Besançon  3.03312e+06  ...        Pierre        Vabres
# 1     Dijon  3.02137e+06  ...        Pierre        Vabres
# 2  Besançon  3.03312e+06  ...        Arthur        Sorlin
# 3     Dijon  3.02137e+06  ...        Arthur        Sorlin
# 4    Ithaca  5.12243e+06  ...  Stanislav S.  Kholmanskikh
#
# [5 rows x 12 columns]

# %%
#
# group by GRIDID and add new column with affiliations count
gridaffiliations["tot_affiliations"] = gridaffiliations.groupby('aff_id')['aff_id'].transform('count')
#
# add new column with publications count, for each GRID
gridaffiliations["tot_pubs"] = gridaffiliations.groupby(['aff_id'])['pub_id'].transform('nunique')
# 
# remove unnecessary columns
gridaffiliations = gridaffiliations.drop(['aff_city_id', 'pub_id', 'researcher_id', 'first_name', 'last_name'], axis=1).reset_index(drop=True)
#
# remove duplicate rows
gridaffiliations.drop_duplicates(inplace=True)
#
# update columns order
gridaffiliations = gridaffiliations[[ 'aff_id', 'aff_name','aff_city', 
                                     'aff_country', 'aff_country_code',  'aff_state',
                                     'aff_state_code', 'tot_affiliations',  'tot_pubs']]
#
# sort
gridaffiliations = gridaffiliations.sort_values(['tot_affiliations', 'tot_pubs'], ascending=False)
#
#
# That's it! Let's see the result
gridaffiliations.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             aff_id                        aff_name  ... tot_affiliations tot_pubs
# 438  grid.66859.34                 Broad Institute  ...             1192      210
# 454  grid.38142.3c              Harvard University  ...              978      245
# 118    grid.5335.0         University of Cambridge  ...              780      145
# 184  grid.10306.34       Wellcome Sanger Institute  ...              683      132
# 463  grid.32224.35  Massachusetts General Hospital  ...              511      132
#
# [5 rows x 9 columns]

# %%
# save the data
gridaffiliations.to_csv("data/4.aggregated-affiliations-with-grid.csv", index=False)

# %%
# download the data 
if COLAB_ENV:
  files.download("data/4.aggregated-affiliations-with-grid.csv")

# %% [markdown]
# ## Couple of Dataviz

# %%
treshold = 100

px.scatter(gridaffiliations[:treshold], x="tot_pubs", y="tot_affiliations", color="aff_country",
           hover_name="aff_name", hover_data=['aff_id', 'aff_name', 'aff_city', 'aff_country', 'tot_affiliations', 'tot_pubs'], 
           title=f"Top {treshold} Institutions: authors & publications")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1d47a85c-f7b2-49bf-add1-ba84858341fc" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1d47a85c-f7b2-49bf-add1-ba84858341fc")) {
#                     Plotly.newPlot(
#                         '1d47a85c-f7b2-49bf-add1-ba84858341fc',
#                         [{"customdata": [["grid.66859.34", "Broad Institute", "Cambridge", "United States", 1192, 210], ["grid.38142.3c", "Harvard University", "Cambridge", "United States", 978, 245], ["grid.32224.35", "Massachusetts General Hospital", "Boston", "United States", 511, 132], ["grid.214458.e", "University of Michigan\u2013Ann Arbor", "Ann Arbor", "United States", 464, 86], ["grid.168010.e", "Stanford University", "Stanford", "United States", 455, 121], ["grid.34477.33", "University of Washington", "Seattle", "United States", 349, 86], ["grid.51462.34", "Memorial Sloan Kettering Cancer Center", "New York", "United States", 348, 51], ["grid.59734.3c", "Icahn School of Medicine at Mount Sinai", "New York", "United States", 347, 88], ["grid.240871.8", "St. Jude Children's Research Hospital", "Memphis", "United States", 326, 23], ["grid.65499.37", "Dana-Farber Cancer Institute", "Boston", "United States", 308, 62], ["grid.266102.1", "University of California, San Francisco", "San Francisco", "United States", 293, 86], ["grid.62560.37", "Brigham and Women's Hospital", "Boston", "United States", 282, 94], ["grid.4367.6", "Washington University in St. Louis", "St Louis", "United States", 265, 62], ["grid.21107.35", "Johns Hopkins University", "Baltimore", "United States", 250, 70], ["grid.25879.31", "University of Pennsylvania", "Philadelphia", "United States", 232, 73], ["grid.10698.36", "University of North Carolina at Chapel Hill", "Chapel Hill", "United States", 221, 66], ["grid.47100.32", "Yale University", "New Haven", "United States", 216, 46], ["grid.266100.3", "University of California, San Diego", "San Diego", "United States", 208, 54], ["grid.39382.33", "Baylor College of Medicine", "Houston", "United States", 206, 58], ["grid.21729.3f", "Columbia University", "New York", "United States", 205, 52], ["grid.42505.36", "University of Southern California", "Los Angeles", "United States", 198, 59], ["grid.19006.3e", "University of California Los Angeles", "Los Angeles", "United States", 196, 72], ["grid.5386.8", "Cornell University", "Ithaca", "United States", 169, 60], ["grid.2515.3", "Boston Children's Hospital", "Boston", "United States", 160, 61], ["grid.270240.3", "Fred Hutchinson Cancer Research Center", "Seattle", "United States", 148, 43], ["grid.48336.3a", "National Cancer Institute", "Rockville", "United States", 134, 27], ["grid.189504.1", "Boston University", "Boston", "United States", 126, 44], ["grid.66875.3a", "Mayo Clinic", "Rochester", "United States", 125, 36], ["grid.240145.6", "The University of Texas MD Anderson Cancer Center", "Houston", "United States", 120, 31], ["grid.21925.3d", "University of Pittsburgh", "Pittsburgh", "United States", 112, 39], ["grid.239844.0", "Harbor\u2013UCLA Medical Center", "Torrance", "United States", 111, 27], ["grid.94365.3d", "National Institutes of Health", "Bethesda", "United States", 107, 39], ["grid.279885.9", "National Heart Lung and Blood Institute", "Bethesda", "United States", 106, 34], ["grid.116068.8", "Massachusetts Institute of Technology", "Cambridge", "United States", 100, 51], ["grid.267308.8", "The University of Texas Health Science Center at Houston", "Houston", "United States", 99, 36], ["grid.26790.3a", "University of Miami", "Coral Gables", "United States", 97, 20]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>aff_country=%{customdata[3]}<br>tot_pubs=%{customdata[5]}<br>tot_affiliations=%{customdata[4]}<br>aff_id=%{customdata[0]}<br>aff_name=%{customdata[1]}<br>aff_city=%{customdata[2]}", "hovertext": ["Broad Institute", "Harvard University", "Massachusetts General Hospital", "University of Michigan\u2013Ann Arbor", "Stanford University", "University of Washington", "Memorial Sloan Kettering Cancer Center", "Icahn School of Medicine at Mount Sinai", "St. Jude Children's Research Hospital", "Dana-Farber Cancer Institute", "University of California, San Francisco", "Brigham and Women's Hospital", "Washington Un ...

# %%
treshold = 500

px.scatter(gridaffiliations[:treshold], x="aff_city", y="tot_pubs", color="aff_country", size='tot_affiliations',
           hover_name="aff_name", hover_data=['aff_id', 'aff_name', 'aff_city', 'aff_country', 'tot_affiliations', 'tot_pubs'], 
           title=f"Top {treshold} Institutions: cities and countries")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="937eda27-e270-4536-85ff-506d3b2ced2f" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("937eda27-e270-4536-85ff-506d3b2ced2f")) {
#                     Plotly.newPlot(
#                         '937eda27-e270-4536-85ff-506d3b2ced2f',
#                         [{"customdata": [["grid.66859.34", "Broad Institute", "Cambridge", "United States", 1192, 210], ["grid.38142.3c", "Harvard University", "Cambridge", "United States", 978, 245], ["grid.32224.35", "Massachusetts General Hospital", "Boston", "United States", 511, 132], ["grid.214458.e", "University of Michigan\u2013Ann Arbor", "Ann Arbor", "United States", 464, 86], ["grid.168010.e", "Stanford University", "Stanford", "United States", 455, 121], ["grid.34477.33", "University of Washington", "Seattle", "United States", 349, 86], ["grid.51462.34", "Memorial Sloan Kettering Cancer Center", "New York", "United States", 348, 51], ["grid.59734.3c", "Icahn School of Medicine at Mount Sinai", "New York", "United States", 347, 88], ["grid.240871.8", "St. Jude Children's Research Hospital", "Memphis", "United States", 326, 23], ["grid.65499.37", "Dana-Farber Cancer Institute", "Boston", "United States", 308, 62], ["grid.266102.1", "University of California, San Francisco", "San Francisco", "United States", 293, 86], ["grid.62560.37", "Brigham and Women's Hospital", "Boston", "United States", 282, 94], ["grid.4367.6", "Washington University in St. Louis", "St Louis", "United States", 265, 62], ["grid.21107.35", "Johns Hopkins University", "Baltimore", "United States", 250, 70], ["grid.25879.31", "University of Pennsylvania", "Philadelphia", "United States", 232, 73], ["grid.10698.36", "University of North Carolina at Chapel Hill", "Chapel Hill", "United States", 221, 66], ["grid.47100.32", "Yale University", "New Haven", "United States", 216, 46], ["grid.266100.3", "University of California, San Diego", "San Diego", "United States", 208, 54], ["grid.39382.33", "Baylor College of Medicine", "Houston", "United States", 206, 58], ["grid.21729.3f", "Columbia University", "New York", "United States", 205, 52], ["grid.42505.36", "University of Southern California", "Los Angeles", "United States", 198, 59], ["grid.19006.3e", "University of California Los Angeles", "Los Angeles", "United States", 196, 72], ["grid.5386.8", "Cornell University", "Ithaca", "United States", 169, 60], ["grid.2515.3", "Boston Children's Hospital", "Boston", "United States", 160, 61], ["grid.270240.3", "Fred Hutchinson Cancer Research Center", "Seattle", "United States", 148, 43], ["grid.48336.3a", "National Cancer Institute", "Rockville", "United States", 134, 27], ["grid.189504.1", "Boston University", "Boston", "United States", 126, 44], ["grid.66875.3a", "Mayo Clinic", "Rochester", "United States", 125, 36], ["grid.240145.6", "The University of Texas MD Anderson Cancer Center", "Houston", "United States", 120, 31], ["grid.21925.3d", "University of Pittsburgh", "Pittsburgh", "United States", 112, 39], ["grid.239844.0", "Harbor\u2013UCLA Medical Center", "Torrance", "United States", 111, 27], ["grid.94365.3d", "National Institutes of Health", "Bethesda", "United States", 107, 39], ["grid.279885.9", "National Heart Lung and Blood Institute", "Bethesda", "United States", 106, 34], ["grid.116068.8", "Massachusetts Institute of Technology", "Cambridge", "United States", 100, 51], ["grid.267308.8", "The University of Texas Health Science Center at Houston", "Houston", "United States", 99, 36], ["grid.26790.3a", "University of Miami", "Coral Gables", "United States", 97, 20], ["grid.280128.1", "National Human Genome Research Institute", "Bethesda", "United States", 89, 32], ["grid.152326.1", "Vanderbilt University", "Nashville", "United States", 88, 32], ["grid.412807.8", "Vanderbilt University Medical Center", "Nashville", "United States", 88, 26], ["grid.223827.e", "University of Utah", "Salt Lake City", "United States", 86, 43], ["grid.17635.36", "University of Minnesota", "Minneapolis", "United States", 84, 38], ["grid.413575.1", "Howard Hughes Medical Institute", "Chevy Chase", "United States", 84, 32], ["grid.241167.7", "Wake Forest University", "Winston-Salem", "United States", 80, 27], ["grid.225279.9", "Cold Spring Harbor Laboratory", "Cold Sp ...
