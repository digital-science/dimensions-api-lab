# %% [markdown]
# <a href="https://colab.research.google.com/github/digital-science/dimensions-api-lab" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open Dimensions API Lab In Google Colab"/></a>

# %% [markdown]
# # Part 5: competing journals
#
# ## Install Dimensions Library and login

# %%
try:
  from google.colab import files
  # %load_ext google.colab.data_table
  COLAB_ENV = True
  # !pip install dimcli plotly_express  -U
  # !mkdir data # to save temp data 
except:
  COLAB_ENV = False


# common libraries
import pandas as pd
from pandas.io.json import json_normalize
import time
import json
from tqdm import tqdm_notebook as tqdm
import plotly_express as px
from getpass import getpass
# FINALLY..
import dimcli
from dimcli.shortcuts import *


##
# LOG IN 
##

USERNAME = "m.pasin@digital-science.com"  #@param {type: "string"}

if not USERNAME:
  print("====\nERROR: Please enter a valid Dimensions API username")
else:
  password = getpass('====\nEnter password here')
  print('=> username is', USERNAME)
  print('=> password is', "*" * len(password))
  dimcli.login(USERNAME, password)
  dsl = dimcli.Dsl()

# %% [markdown]
# # Competing Journals

# %% [markdown]
# From our researchers master list, we now want to extract the following:
#
# * full list of publications for a 5 year period
# * full list of journals with counts of how many publications per journal
#
# This new dataset will let us draw up some conclusions re. which are the competing journals of the one we selected at the beginning.

# %% [markdown]
# #### First let's reload the data obtained in previous steps

# %%
#
journal_id = "jour.1103138" # Nature genetics
start_year = 2015 
#
researchers = pd.read_csv("data/2.researchers_impact_metrics.csv")
#

# %%
print("Total researchers:", len(researchers))
researchers.head(5)
# Out:
# Total researchers: 17440
#        researcher_id  ...                                                url
# 0   ur.0723426172.10  ...  https://app.dimensions.ai/discover/publication...
# 1  ur.01277776417.51  ...  https://app.dimensions.ai/discover/publication...
# 2   ur.0641525362.39  ...  https://app.dimensions.ai/discover/publication...
# 3   ur.0637651205.48  ...  https://app.dimensions.ai/discover/publication...
# 4  ur.01313145634.66  ...  https://app.dimensions.ai/discover/publication...
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Two possible approaches in this case

# %% [markdown]
# The easy way is to use the 'journals' facet on publications data.
#
# This approach is quick and good enough to get a feeling for the top competitors. However
# * this approach will end up including duplicates
# * there might be a long tail of journals with very few publications that are lsot

# %%
# %%dsldf
# search publications where researchers.id in ["ur.01277776417.51", "ur.0637651205.48"]
# and year >= 2015 and journal.id != "jour.1103138" return journal limit 1000
# Out:
# Returned Journal: 38
#     count            id                                              title
# 0      32  jour.1043282                              Nature Communications
# 1      14  jour.1293558                                            bioRxiv
# 2       6  jour.1018957                                             Nature
# 3       6  jour.1034974                                      PLoS Genetics
# 4       4  jour.1102504                           Human Molecular Genetics
# 5       3  jour.1091325                             European Heart Journal
# 6       3  jour.1300829                             Communications Biology
# 7       2  jour.1017423                                           Diabetes
# 8       2  jour.1024947                               BMC Medical Genetics
# 9       2  jour.1045271                           Translational Psychiatry
# 10      2  jour.1045337                                 Scientific Reports
# 11      2  jour.1050678                                    Scientific Data
# 12      2  jour.1082971    Proceedings of the National Academy of Sciences
# 13      2  jour.1103682                       Osteoarthritis and Cartilage
# 14      2  jour.1115540                               Molecular Psychiatry
# 15      2  jour.1312325                        Journal of Chromatography B
# 16      2  jour.1346339                                            Science
# 17      1  jour.1009646                  Molecular Genetics and Metabolism
# 18      1  jour.1013420                                    Atherosclerosis
# 19      1  jour.1017012             The American Journal of Human Genetics
# 20      1  jour.1022095   American Journal of Physiology - Cell Physiology
# 21      1  jour.1023439                                     Genome Biology
# 22      1  jour.1037224  International Journal of Data Mining and Bioin...
# 23      1  jour.1039060            Forensic Science International Genetics
# 24      1  jour.1040791         Circulation Genomic and Precision Medicine
# 25      1  jour.1045166                            Frontiers in Immunology
# 26      1  jour.1053748                               npj Genomic Medicine
# 27      1  jour.1085025                                              Blood
# 28      1  jour.1086831                                Annals of Neurology
# 29      1  jour.1093746      Journal of the American College of Cardiology
# 30      1  jour.1096580               Journal of Bone and Mineral Research
# 31      1  jour.1099130                              Phytotherapy Research
# 32      1  jour.1100229              European Journal of Internal Medicine
# 33      1  jour.1100486                         Journal of Dental Research
# 34      1  jour.1100952   Arteriosclerosis Thrombosis and Vascular Biology
# 35      1  jour.1101548                   European Neuropsychopharmacology
# 36      1  jour.1115233                                  Addiction Biology
# 37      1  jour.1358108           Journal of the National Cancer Institute

# %% [markdown]
# **Second approach**: pulling all publications data and doing the counting programmatically using the data.
#
# This takes longer, and requires more processing, but it is much more precise.

# %%
# %%dsldf
# search publications where researchers.id in ["ur.01277776417.51", "ur.0637651205.48"]
# and year >= 2015 and journal is not empty
# and journal.id != "jour.1103138" return publications[id+journal] limit 1000
# Out:
# Returned Publications: 109 (total = 109)
#                  id  ...                                      journal.title
# 0    pub.1113477375  ...                              Nature Communications
# 1    pub.1112876837  ...                              Nature Communications
# 2    pub.1111326269  ...                              Nature Communications
# 3    pub.1113901526  ...                              Nature Communications
# 4    pub.1115929591  ...                  Molecular Genetics and Metabolism
# 5    pub.1113239657  ...                                            bioRxiv
# 6    pub.1110156056  ...                           Human Molecular Genetics
# 7    pub.1111648957  ...                                            Science
# 8    pub.1112983752  ...                   European Neuropsychopharmacology
# 9    pub.1110758233  ...                                      PLoS Genetics
# 10   pub.1110204810  ...                              Nature Communications
# 11   pub.1104438507  ...                             Communications Biology
# 12   pub.1105714095  ...                              Nature Communications
# 13   pub.1103889346  ...                             Communications Biology
# 14   pub.1106545297  ...                              Nature Communications
# 15   pub.1106858931  ...                              Nature Communications
# 16   pub.1100796116  ...                             Communications Biology
# 17   pub.1104381158  ...                              Nature Communications
# 18   pub.1107871600  ...                              Nature Communications
# 19   pub.1101298929  ...                              Nature Communications
# 20   pub.1106295007  ...                              Nature Communications
# 21   pub.1107733474  ...                              Nature Communications
# 22   pub.1105524469  ...                                     Genome Biology
# 23   pub.1101325713  ...                             European Heart Journal
# 24   pub.1100277820  ...           Journal of the National Cancer Institute
# 25   pub.1092056577  ...                               Molecular Psychiatry
# 26   pub.1104345707  ...                        Journal of Chromatography B
# 27   pub.1107639515  ...         Circulation Genomic and Precision Medicine
# 28   pub.1101608943  ...                             European Heart Journal
# 29   pub.1100623522  ...                         Journal of Dental Research
# ..              ...  ...                                                ...
# 79   pub.1005992890  ...                        Journal of Chromatography B
# 80   pub.1018405032  ...             The American Journal of Human Genetics
# 81   pub.1002371806  ...   American Journal of Physiology - Cell Physiology
# 82   pub.1010852527  ...                                             Nature
# 83   pub.1024821656  ...                               Molecular Psychiatry
# 84   pub.1043049406  ...                              Nature Communications
# 85   pub.1030295458  ...                              Nature Communications
# 86   pub.1006456041  ...                              Nature Communications
# 87   pub.1048671587  ...                           Human Molecular Genetics
# 88   pub.1024423633  ...                              Phytotherapy Research
# 89   pub.1009170264  ...               Journal of Bone and Mineral Research
# 90   pub.1041341312  ...                                            bioRxiv
# 91   pub.1026621968  ...                                    Scientific Data
# 92   pub.1023789407  ...                              Nature Communications
# 93   pub.1007709897  ...                              Nature Communications
# 94   pub.1023225532  ...            Forensic Science International Genetics
# 95   pub.1014034212  ...                              Nature Communications
# 96   pub.1002446865  ...                              Nature Communications
# 97   pub.1005287207  ...                              Nature Communications
# 98   pub.1014032763  ...                                      PLoS Genetics
# 99   pub.1039034540  ...                                             Nature
# 100  pub.1029106514  ...                           Translational Psychiatry
# 101  pub.1001569005  ...                                      PLoS Genetics
# 102  pub.1006205436  ...                                    Atherosclerosis
# 103  pub.1030553717  ...                                      PLoS Genetics
# 104  pub.1045369307  ...   Arteriosclerosis Thrombosis and Vascular Biology
# 105  pub.1031548725  ...                                           Diabetes
# 106  pub.1053003561  ...                                             Nature
# 107  pub.1019263071  ...                                             Nature
# 108  pub.1067446319  ...  International Journal of Data Mining and Bioin...
#
# [109 rows x 3 columns]

# %% [markdown]
# ## Using the second approach to extract all publications/journals information
#
# This approach will take more time (eg about ~30 mins or more) but the results we get are guaranteed to be precise and complete.

# %%
# our list of researchers
llist = list(researchers['researcher_id'])
#
# the query
q2 = """search publications where researchers.id in {} 
and year >= {} and journal is not empty and journal.id != "{}" 
return publications[id+journal]"""

# %%
#
# helper to extract and simplify nested journal data
def get_journal_data(x):
  # simplify nested dict and store results
  if type(x['journal']) == dict:
      x['journal_id'] = x['journal']['id']
      x['title'] = x['journal']['title']
      del x["journal"]  
      return x 
  return None
#
#
# iterate 200 researchers per loop
out = []
for chunk in tqdm(list(chunks_of(llist, 200))):
    res = dslqueryall(q2.format(json.dumps(chunk), start_year, journal_id))
    for x in res.publications:
        if get_journal_data(x):
            out.append(x)
    time.sleep(1)
#
# save to a df
journals = pd.DataFrame().from_dict(out)
#
# remove duplicate journals if they have the same PUB_ID
journals = journals.drop_duplicates()
journals.to_csv("data/5.journals-via-publications-RAW.csv", index=False)
#
# now drop pub_id column
journals = journals.drop(['id'], axis=1)
#
# add total column 
journals['total'] = journals.groupby('journal_id')['journal_id'].transform('count')
#
# remove multiple counts for same journal, after countin
journals = journals.drop_duplicates() 
#
# sort by total count
journals = journals.sort_values('total', ascending=False)
#
# save
journals.to_csv("data/5.journals-via-publications.csv", index=False)
print("======\nDone")

# %%
#preview the data 
journals.head(5)
# Out:
#         journal_id                         title  total
# 177   jour.1293558                       bioRxiv   9691
# 822   jour.1312191  Journal of Clinical Oncology   7239
# 263   jour.1037553                      PLoS ONE   6905
# 2     jour.1045337            Scientific Reports   5626
# 1177  jour.1034467        Alzheimer's & Dementia   3336

# %%
# download the data
if COLAB_ENV:
  files.download("data/5.journals-via-publications.csv")

# %% [markdown]
# # Visualization

# %%
threshold = 500

px.bar(df2[:threshold], x="title", y="total", hover_name="title", 
           hover_data=['journal_id', 'title', 'total' ], 
           title=f"Top competitors for {journal_id} (based on data from {start_year})")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2748aade-b2a4-4564-b57f-0b9e2a794b89" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2748aade-b2a4-4564-b57f-0b9e2a794b89")) {
#                     Plotly.newPlot(
#                         '2748aade-b2a4-4564-b57f-0b9e2a794b89',
#                         [{"alignmentgroup": "True", "customdata": [["jour.1293558", "bioRxiv", 9691], ["jour.1312191", "Journal of Clinical Oncology", 7239], ["jour.1037553", "PLoS ONE", 6905], ["jour.1045337", "Scientific Reports", 5626], ["jour.1034467", "Alzheimer's & Dementia", 3336], ["jour.1043282", "Nature Communications", 3004], ["jour.1043645", "Oncotarget", 2753], ["jour.1017616", "Gastroen