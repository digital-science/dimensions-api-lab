# %% [markdown]
# # Exploring The Dimensions Search Language (DSL) - Quick Intro
#
# This Notebook takes you through the basics of using the Dimensions API.
#
# > See also: [official DSL documentation online](https://docs.dimensions.ai/dsl/)
#
# In this tutorial we leverage the capabilities of the [Dimcli library](https://github.com/lambdamusic/dimcli) in the context of Jupyter Notebooks. Dimcli is an open source Python library that simplifies common operations like logging in, querying and displaying results.

# %% [markdown]
# ### Prerequisites
#
# This notebook assumes you have installed the [Dimcli](https://pypi.org/project/dimcli/) library and are familiar with the *Getting Started* tutorial.

# %%
# !pip install dimcli -U --quiet 

import dimcli
from dimcli.utils import *
import sys

print("==\nLogging in..")
# https://digital-science.github.io/dimcli/getting-started.html#authentication
ENDPOINT = "https://app.dimensions.ai"
if 'google.colab' in sys.modules:
  import getpass
  KEY = getpass.getpass(prompt='API Key: ')  
  dimcli.login(KEY, ENDPOINT)
else:
  KEY = ""
  dimcli.login(KEY, ENDPOINT)
dsl = dimcli.Dsl()
# Out:
# ==
# Logging in..
# Dimcli - Dimensions API Client (v0.8.2)
# Connected to: https://app.dimensions.ai - DSL v1.28
# Method: dsl.ini file

# %% [markdown]
# ## What the query statistics refer to
#
# When performing a DSL search, a `_stats` object is return which contains some useful info eg the total number of records available for a search.

# %%
res1 = dsl.query("""
  search publications
  where year in [2013:2018] and research_orgs="grid.258806.1"
  return publications""", verbose=False)
print(res1.stats) # PS this is short for `res.json['_stats'])`
# Out:
# {'total_count': 3727}

# %% [markdown]
# It is important to note though that the **total number always refers to the main source** one is searching for, not necessarily the results being returned. For example, in this query we return `researchers` linked to publications:

# %%
res2 = dsl.query("""
  search publications
  where year in [2013:2018] and research_orgs="grid.258806.1"
  return researchers""", verbose=False)
print(res2.stats)
# Out:
# {'total_count': 3727}

# %% [markdown]
# Still 3815 records! That's because the total count always refers to the main object type one is searching for, not to the *facet* being returned.

# %% [markdown]
# Tip: this basic information about objects returned is also available via the `count_batch` and `count_total` methods of the query results object.

# %%
result = dsl.query("""
     search publications
       for "malaria AND congo"
     return publications[basics]
     limit 30
""", verbose=False)
# print some stats using the Result object
print("Results in this batch: ", result.count_batch)
print("Results in total: ", result.count_total)
print("Errors: ",result.errors)
# Out:
# Results in this batch:  30
# Results in total:  71812
# Errors:  None

# %% [markdown]
# ## Working with fields
#
# Note: in the following examples we use the magic command `%%dsldf` for quicker querying.
#
# ### Control the fields you return

# %%
# %%dsldf
#
# search publications
# return publications[id+title+year+doi]
# limit 5
# Out:
# Returned Publications: 5 (total = 112275334)
# Time: 1.41s
#                                                title  year              id  \
# 0                                         Literature  2020  pub.1125632078
# 1  To start or to complete? – Challenges in imple...  2020  pub.1124099280
# 2  Long-term trends in seasonality of mortality i...  2020  pub.1124649186
# 3  Eine Warnung an alle, dy sych etwaz duncken: D...  2020  pub.1125632729
# 4                             Marienklagen und Pietà  2020  pub.1125635978
#
#                              doi
# 0      10.1515/9783110823547-013
# 1  10.1080/16549716.2019.1704540
# 2  10.1080/16549716.2020.1717411
# 3      10.1515/9783110950762-012
# 4      10.1515/9783110922035-011

# %% [markdown]
# ### Make a mistake, and the DSL will tell you what fields that you could have used

# %%
# %%dsldf
#
# search publications
# return publications[dois]
# limit 100
# Out:
# Returned Errors: 1
# Time: 0.45s
# Semantic Error
# Semantic errors found:
# 	Field / Fieldset 'dois' is not present in Source 'publications'. Available fields: FOR,FOR_first,HRCS_HC,HRCS_RAC,RCDC,altmetric,altmetric_id,author_affiliations,authors,book_doi,book_series_title,book_title,category_bra,category_for,category_hra,category_hrcs_hc,category_hrcs_rac,category_icrp_cso,category_icrp_ct,category_rcdc,category_sdg,category_ua,category_uoa,concepts,concepts_scores,date,date_inserted,dimensions_url,doi,field_citation_ratio,funder_countries,funders,id,issn,issue,journal,journal_lists,linkout,mesh_terms,open_access,open_access_categories,pages,pmcid,pmid,proceedings_title,publisher,recent_citations,reference_ids,referenced_pubs,references,relative_citation_ratio,research_org_cities,research_org_countries,research_org_country_names,research_org_names,research_org_state_codes,research_org_state_names,research_orgs,researchers,resulting_publication_doi,supporting_grant_ids,terms,times_cited,title,type,volume,year and available fieldsets: all,basics,book,categories,extras

# %% [markdown]
# ### Get all fields

# %%
# %%dsldf
#
# search publications
#   for "malaria"
# return publications[all]
# limit 1
# Out:
# Returned Publications: 1 (total = 786126)
# Time: 0.92s
# WARNINGS [10]
# Field 'references' is deprecated in favor of reference_ids. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details
# Field 'terms' is deprecated in favor of concepts. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details
# Field 'RCDC' is deprecated in favor of category_rcdc. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details
# Field 'HRCS_RAC' is deprecated in favor of category_hrcs_rac. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details
# Field 'FOR' is deprecated in favor of category_for. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details
# Field 'author_affiliations' is deprecated in favor of authors. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details
# Field 'category_ua' is deprecated in favor of category_uoa. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details
# Field 'HRCS_HC' is deprecated in favor of category_hrcs_hc. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details
# Field 'open_access' is deprecated in favor of open_access_categories. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details
# Field 'FOR_first' is deprecated in favor of category_for. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details
#                                                title  \
# 0  Long-term trends in seasonality of mortality i...
#
#                                                terms     type  \
# 0  [patterns, mortality, Sub-Saharan Africa, chan...  article
#
#    recent_citations                                    referenced_pubs  year  \
# 0                 1  [{'id': 'pub.1070577469', 'doi': '10.2307/4148...  2020
#
#                                          category_ua  \
# 0  [{'id': '30002', 'name': 'A02 Public Health, H...
#
#                               research_org_countries  \
# 0  [{'id': 'US', 'name': 'United States'}, {'id':...
#
#                                  research_org_cities  \
# 0  [{'id': 2792073, 'name': 'Louvain-la-Neuve'}, ...
#
#                                              linkout  ...  \
# 0  https://www.tandfonline.com/doi/pdf/10.1080/16...  ...
#
#                                         category_uoa         publisher  \
# 0  [{'id': '30002', 'name': 'A02 Public Health, H...  Taylor & Francis
#
#                                    RCDC  \
# 0  [{'id': '547', 'name': 'Pediatric'}]
#
#                                        category_hra altmetric_id  \
# 0  [{'id': '3903', 'name': 'Population & Society'}]     75135566
#
#                                             concepts      pmid  \
# 0  [cause-specific mortality, cause mortality, ep...  32027239
#
#   research_org_state_names    journal.id         journal.title
# 0             [New Jersey]  jour.1041075  Global Health Action
#
# [1 rows x 51 columns]

# %% [markdown]
# ## Full text search
#
# You can search for full text in the full text, in abstracts or in the title only.

# %%
# %dsldf search publications in concepts for "situ detection OR malaria" return publications
# Out:
# Returned Publications: 20 (total = 201452)
# Time: 1.08s
#                                                 title      pages  \
# 0   Breeding soundness examination and herd profic...    840-855
# 1   In‐situ sol–gel synthesis of zirconia networks...      49506
# 2   Hierarchical NiCo2O4-MnO x -NF monolithic cata...     147485
# 3   Nanostructured selenium-doped biphasic calcium...      13738
# 4   MRI of prostatic urethral mucinous urothelial ...      68-70
# 5   In vitro modeling of the neurovascular unit: a...         22
# 6   Bacterial cellulose: From production optimizat...  2598-2611
# 7   Hydrogen sulfide removal from geothermal fluid...         21
# 8   Manufacturing and characterization of in-situ ...     101436
# 9   Relative survival in early-stage cancers in th...         49
# 10  An In-situ and Direct Confirmation of Super-Pl...       5209
# 11  In situ simulation training in helicopter emer...          7
# 12  In-situ Growth of ZIF-8 in Amphiphilic Graft C...     117514
# 13  Finding cell-specific expression patterns in t...       4961
# 14  Unravelling three-dimensional adsorption geome...         28
# 15  Network hub-node prioritization of gene regula...        101
# 16  Sebaceous carcinoma of the breast predominantl...         41
# 17  Ethnomycological study of edible and medicinal...         11
# 18    Mechanical breathing in organic electrochromics        211
# 19  Improved kinetic behaviour of Mg(NH2)2-2LiH do...          8
#
#                                   author_affiliations  year issue  \
# 0   [[{'first_name': 'Víctor Fernando', 'last_name...  2020     1
# 1   [[{'first_name': 'Mohammad Hossein', 'last_nam...  2020    46
# 2   [[{'first_name': 'Dongdong', 'last_name': 'Wan...  2020   NaN
# 3   [[{'first_name': 'Lei', 'last_name': 'Nie', 'c...  2020     1
# 4   [[{'first_name': 'Neel', 'last_name': 'Patel',...  2020   NaN
# 5   [[{'first_name': 'Aditya', 'last_name': 'Bhale...  2020     1
# 6   [[{'first_name': 'Isabela', 'last_name': 'de A...  2020   NaN
# 7   [[{'first_name': 'S.', 'last_name': 'Regenspur...  2020     1
# 8   [[{'first_name': 'A.M.', 'last_name': 'Vilarde...  2020   NaN
# 9   [[{'first_name': 'Avinash G.', 'last_name': 'D...  2020     1
# 10  [[{'first_name': 'Shawn-Yu', 'last_name': 'Lin...  2020     1
# 11  [[{'first_name': 'Per P.', 'last_name': 'Bredm...  2020     1
# 12  [[{'first_name': 'Chang Soo', 'last_name': 'Le...  2020   NaN
# 13  [[{'first_name': 'Garth R.', 'last_name': 'Ils...  2020     1
# 14  [[{'first_name': 'Jaco J.', 'last_name': 'Geuc...  2020     1
# 15  [[{'first_name': 'Hung-Ching', 'last_name': 'C...  2020     1
# 16  [[{'first_name': 'Koichi', 'last_name': 'Ohno'...  2020     1
# 17  [[{'first_name': 'Rediet', 'last_name': 'Sitot...  2020     1
# 18  [[{'first_name': 'Xiaokang', 'last_name': 'Wan...  2020     1
# 19  [[{'first_name': 'Gökhan', 'last_name': 'Gizer...  2020     1
#
#                 id     type volume    journal.id  \
# 0   pub.1130093974  article     19  jour.1032284
# 1   pub.1128193344  article    137  jour.1135048
# 2   pub.1130006001  article    532  jour.1038686
# 3   pub.1130064403  article     10  jour.1045337
# 4   pub.1128497262  article     68  jour.1087975
# 5   pub.1125684242  article     17  jour.1034919
# 6   pub.1129823711  article    164  jour.1090368
# 7   pub.1129357222  article      8  jour.1136002
# 8   pub.1128995596  article     36  jour.1147513
# 9   pub.1127549599  article     13  jour.1039771
# 10  pub.1125822283  article     10  jour.1045337
# 11  pub.1128482253  article      5  jour.1327571
# 12  pub.1129930273  article    253  jour.1380465
# 13  pub.1125710140  article     10  jour.1045337
# 14  pub.1125315284  article      3  jour.1319511
# 15  pub.1125610909  article     21  jour.1023786
# 16  pub.1125102540  article      6  jour.1052102
# 17  pub.1125400666  article     16  jour.1035305
# 18  pub.1124004513  article     11  jour.1043282
# 19  pub.1123884363  article     10  jour.1045337
#
#                                         journal.title
# 0                   Italian Journal of Animal Science
# 1                  Journal of Applied Polymer Science
# 2                             Applied Surface Science
# 3                                  Scientific Reports
# 4                                    Clinical Imaging
# 5                      Fluids and Barriers of the CNS
# 6   International Journal of Biological Macromolec...
# 7                                   Geothermal Energy
# 8                              Additive Manufacturing
# 9                    Journal of Hematology & Oncology
# 10                                 Scientific Reports
# 11                             Advances in Simulation
# 12             Separation and Purification Technology
# 13                                 Scientific Reports
# 14                           Communications Chemistry
# 15                                 BMC Bioinformatics
# 16                              Surgical Case Reports
# 17          Journal of Ethnobiology and Ethnomedicine
# 18                              Nature Communications
# 19                                 Scientific Reports

# %%
# %%dsldf
#
# search publications in title_abstract_only for "nanotechnology"
# return publications
# limit 3
# Out:
# Returned Publications: 3 (total = 78065)
# Time: 0.60s
#                                                title      pages  \
# 0  The inventions in nanotechnologies as practica...    719-729
# 1  The Development of Antibiotics Based on Nanost...  7618-7628
# 2  Interactions Between Remdesivir, Ribavirin, Fa...  7311-7323
#
#                                  author_affiliations  year issue  \
# 0  [[{'first_name': 'L.A.', 'last_name': 'Ivanov'...  2020     6
# 1  [[{'first_name': 'Ayesha', 'last_name': 'Taj',...  2020    12
# 2  [[{'first_name': 'Tiago da', 'last_name': 'Sil...  2020    12
#
#                id     type volume    journal.id  \
# 0  pub.1125757275  article     11  jour.1153140
# 1  pub.1129669026  article     20  jour.1297328
# 2  pub.1129669004  article     20  jour.1297328
#
#                                        journal.title
# 0  Nanotechnologies in Construction A Scientific ...
# 1          Journal of Nanoscience and Nanotechnology
# 2          Journal of Nanoscience and Nanotechnology

# %% [markdown]
# ### A simple author search

# %%
# %%dsldf
#
# search publications in authors for "\"Daniel Hook\""
# return publications
# limit 10
# Out:
# Returned Publications: 10 (total = 78)
# Time: 0.55s
#                id                                              title volume  \
# 0  pub.1124226668  Dimensions: Bringing down barriers between sci...      1
# 1  pub.1115957159                  Perception, prestige and PageRank     14
# 2  pub.1119449118                      The Price of Gold: Curiosity?    NaN
# 3  pub.1118864658                  Perception, Prestige and PageRank    NaN
# 4  pub.1108567148                                        PT Symmetry    NaN
# 5  pub.1111011264  Optical Fiber Sensor Design for Ground Slope M...     00
# 6  pub.1106289502  Dimensions: Building Context for Search and Ev...      3
# 7  pub.1105321123  Assessment of the interaction between a natura...     41
# 8  pub.1085413261  Characterization and quantitation of PVP conte...    106
# 9  pub.1085511076  Behavior of eigenvalues in a region of broken ...     95
#
#   issue      pages        type  year  \
# 0     1    387-395     article  2020
# 1     5   e0216783     article  2019
# 2   NaN        NaN    preprint  2019
# 3   NaN        NaN    preprint  2019
# 4   NaN        NaN   monograph  2019
# 5   NaN        1-4  proceeding  2018
# 6   NaN         23     article  2018
# 7   NaN        s45     article  2018
# 8     3  1064-1072     article  2018
# 9     5     052113     article  2017
#
#                                  author_affiliations    journal.id  \
# 0  [[{'first_name': 'Christian', 'last_name': 'He...  jour.1377615
# 1  [[{'first_name': 'David', 'last_name': 'Zeitly...  jour.1037553
# 2  [[{'first_name': 'Daniel W.', 'last_name': 'Ho...  jour.1371339
# 3  [[{'first_name': 'David', 'last_name': 'Zeitly...  jour.1371339
# 4  [[{'first_name': 'Carl M', 'last_name': 'Bende...           NaN
# 5  [[{'first_name': 'Daniel', 'last_name': 'Hook'...           NaN
# 6  [[{'first_name': 'Daniel W.', 'last_name': 'Ho...  jour.1292498
# 7  [[{'first_name': 'Daniel', 'last_name': 'Hook'...  jour.1091476
# 8  [[{'first_name': 'Andrew J.', 'last_name': 'Ho...  jour.1312091
# 9  [[{'first_name': 'Carl M.', 'last_name': 'Bend...  jour.1053349
#
#                                        journal.title
# 0                       Quantitative Science Studies
# 1                                           PLoS ONE
# 2                                              arXiv
# 3                                              arXiv
# 4                                                NaN
# 5                                                NaN
# 6        Frontiers in Research Metrics and Analytics
# 7                      Contact Lens and Anterior Eye
# 8  Journal of Biomedical Materials Research Part ...
# 9                                  Physical Review A

# %% [markdown]
# ### ..or search for a researcher by a specific id

# %%
# %%dsldf
#
# search publications
# where researchers.id = "ur.013514345521.07"
# return publications[doi+researchers]
# limit 1
# Out:
# Returned Publications: 1 (total = 16)
# Time: 0.48s
#                          doi  \
# 0  10.1038/s41385-020-0334-2
#
#                                          researchers
# 0  [{'id': 'ur.015441462403.62', 'last_name': 'Be...

# %% [markdown]
# ## Sources VS Facets
# One of the queries above is using the `researchers` facet of the `publications` source.
#
# In general source-queries can return up to 1000 records. For example this throws an exception:

# %%
dsl.query("""
  search publications
  where year in [2013:2018] and research_orgs="grid.258806.1"
  return publications limit 2000
  """)
# Out:
# Returned Errors: 1
# Time: 0.45s
# Semantic Error
# Semantic errors found:
# 	Limit 2000 exceeds maximum allowed limit 1000
# <dimcli.DslDataset object #4523680624. Errors: 1>

# %% [markdown]
# ### You can paginate through *source* results up to 50000 rows
#
# With [sources](https://docs.dimensions.ai/dsl/data-sources.html), you can use the [limit/skip syntax](https://docs.dimensions.ai/dsl/language.html#paginating-results) in order to paginate through results:

# %%
dsl.query("""
  search publications
  where year in [2013:2018] and research_orgs="grid.258806.1"
  return publications limit 1000 skip 1000
  """)
# Out:
# Returned Publications: 1000 (total = 3727)
# Time: 2.38s
# <dimcli.DslDataset object #4506154128. Records: 1000/3727>

# %% [markdown]
# ### You can return max 1000 `facet` rows
#
# It is important to remember that [when using facets](https://docs.dimensions.ai/dsl/language.html#returning-facets) you cannot use the *skip* operation so the maximum number of records is always 1000.

# %%
dsl.query("""
  search publications
  where year in [2013:2018] and research_orgs="grid.258806.1"
  return researchers limit 1 skip 1000
  """)
# Out:
# Returned Errors: 1
# Time: 0.44s
# Semantic Error
# Semantic errors found:
# 	Offset is not supported for facet results
# <dimcli.DslDataset object #4770861936. Errors: 1>

# %% [markdown]
# While this works...

# %%
dsl.query("""
  search publications
  where year in [2013:2018] and research_orgs="grid.258806.1"
  return researchers limit 1000
  """)
# Out:
# Returned Researchers: 1000
# Time: 1.64s
# <dimcli.DslDataset object #4523681536. Records: 1000/3727>

# %% [markdown]
# ### Just make a mistake, and you will ge the complete list of available facets

# %%
dsl.query("""
search publications 
return years 
""")
# Out:
# Returned Errors: 1
# Time: 0.46s
# Semantic Error
# Semantic errors found:
# 	Facet 'years' is not present in source 'publications'. Available facets are: FOR,FOR_first,HRCS_HC,HRCS_RAC,RCDC,category_bra,category_for,category_hra,category_hrcs_hc,category_hrcs_rac,category_icrp_cso,category_icrp_ct,category_rcdc,category_sdg,category_ua,category_uoa,experts,funder_countries,funders,journal,journal_lists,mesh_terms,open_access_categories,pf01,publisher,referenced_pubs,research_org_cities,research_org_countries,research_org_state_codes,research_orgs,researchers,times_cited,type,year
# <dimcli.DslDataset object #4779131712. Errors: 1>
