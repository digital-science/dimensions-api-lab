# %% [markdown]
# <a href="https://colab.research.google.com/github/digital-science/dimensions-api-lab/blob/master/3-workshops/2019-06-Rotterdam-University/1-Exploring-the-DSL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open Dimensions API Lab In Google Colab"/></a>

# %% [markdown]
# # Exploring The Dimensions  API
#
# This Notebook takes you through the basics of using the Dimensions API with Jupyter Notebooks.

# %%
from dimcli.shortcuts import dslquery_json as dslquery

# %% [markdown]
# ## The Basics
#
# The dslquery function works in just the same way as the dimensions API inteface works in the application.
# * submit your query
# * get back json results

# %%
#A Basic Query  

dslquery("""
     search publications
       where id = "pub.1104296509"
     return publications[all]
     limit 1
""")
# Out:
# {'_stats': {'total_count': 1, 'limit': 1, 'offset': 0},
#  '_warnings': ["Field 'terms' is deprecated in favor of concepts. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details",
#   "Field 'open_access' is deprecated in favor of open_access_categories. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details",
#   "Field 'references' is deprecated in favor of reference_ids. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details"],
#  'publications': [{'author_affiliations': [[{'first_name': 'Ester M.',
#       'last_name': 'Palmero',
#       'orcid': "['0000-0001-8223-3200']",
#       'current_organization_id': 'grid.452504.2',
#       'researcher_id': 'ur.013741637062.76',
#       'affiliations': [{'id': 'grid.482876.7',
#         'name': 'IMDEA Nanoscience',
#         'city': 'Madrid',
#         'city_id': 3117735,
#         'country': 'Spain',
#         'country_code': 'ES',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Javier',
#       'last_name': 'Rial',
#       'orcid': '',
#       'current_organization_id': 'grid.482876.7',
#       'researcher_id': 'ur.07414614063.30',
#       'affiliations': [{'id': 'grid.482876.7',
#         'name': 'IMDEA Nanoscience',
#         'city': 'Madrid',
#         'city_id': 3117735,
#         'country': 'Spain',
#         'country_code': 'ES',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Javier',
#       'last_name': 'de Vicente',
#       'orcid': '',
#       'current_organization_id': 'grid.482876.7',
#       'researcher_id': 'ur.013235051422.01',
#       'affiliations': [{'id': 'grid.482876.7',
#         'name': 'IMDEA Nanoscience',
#         'city': 'Madrid',
#         'city_id': 3117735,
#         'country': 'Spain',
#         'country_code': 'ES',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Julio',
#       'last_name': 'Camarero',
#       'orcid': "['0000-0003-0078-7280']",
#       'current_organization_id': 'grid.5515.4',
#       'researcher_id': 'ur.01027655236.11',
#       'affiliations': [{'id': 'grid.482876.7',
#         'name': 'IMDEA Nanoscience',
#         'city': 'Madrid',
#         'city_id': 3117735,
#         'country': 'Spain',
#         'country_code': 'ES',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Björn',
#       'last_name': 'Skårman',
#       'orcid': '',
#       'current_organization_id': 'grid.424709.c',
#       'researcher_id': 'ur.014623751315.63',
#       'affiliations': [{'id': 'grid.424709.c',
#         'name': 'Höganäs (Sweden)',
#         'city': 'Höganäs',
#         'city_id': 2706003,
#         'country': 'Sweden',
#         'country_code': 'SE',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Hilmar',
#       'last_name': 'Vidarsson',
#       'orcid': '',
#       'current_organization_id': 'grid.424709.c',
#       'researcher_id': 'ur.01156222124.78',
#       'affiliations': [{'id': 'grid.424709.c',
#         'name': 'Höganäs (Sweden)',
#         'city': 'Höganäs',
#         'city_id': 2706003,
#         'country': 'Sweden',
#         'country_code': 'SE',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Per-Olof',
#       'last_name': 'Larsson',
#       'orcid': '',
#       'current_organization_id': 'grid.8148.5',
#       'researcher_id': 'ur.071444746.01',
#       'affiliations': [{'id': 'grid.424709.c',
#         'name': 'Höganäs (Sweden)',
#         'city': 'Höganäs',
#         'city_id': 2706003,
#         'country': 'Sweden',
#         'country_code': 'SE',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Alberto',
#       'last_name': 'Bollero',
#       'orcid': "['0000-0002-3282-0981']",
#       'current_organization_id': 'grid.482876.7',
#       'researcher_id': 'ur.0763542206.68',
#       'affiliations': [{'id': 'grid.482876.7',
#         'name': 'IMDEA Nanoscience',
#         'city': 'Madrid',
#         'city_id': 3117735,
#         'country': 'Spain',
#         'country_code': 'ES',
#         'state': None,
#         'state_code': None}]}]],
#    'funders': [{'id': 'grid.418921.7',
#      'name': 'Comunidad de Madrid',
#      'country_name': 'Spain'},
#     {'id': 'grid.451322.3',
#      'acronym': 'MINECO',
#      'name': 'Ministry of Economy, Industry and Competitiveness',
#      'country_name': 'Spain'}],
#    'journal': {'id': 'jour.1048844',
#     'title': 'Science and Technology of Advanced Materials'},
#    'altmetric_id': 43292476,
#    'issn': ['1468-6996', '1878-5514'],
#    'FOR': [{'id': '2921', 'name': '0912 Materials Engineering'}],
#    'concepts': ['content',
#     'flexible filaments',
#     'system',
#     'polyethylene',
#     'shape',
#     'traditional manufacturing',
#     'fabrication',
#     'filament extrusion',
#     'composite materials',
#     'deterioration',
#     'efficiency',
#     'transport applications',
#     'compacted magnet',
#     'precursor',
#     'manufacturing restrictions',
#     'structure',
#     'matrix',
#     'technological applications',
#     'aerospace sector',
#     'processing techniques',
#     'homogeneous composites',
#     'related technologies',
#     'scalable design',
#     'synthesis',
#     'final device',
#     'spherical particles',
#     'properties',
#     'application',
#     'magnets',
#     'gas',
#     'composites',
#     'length',
#     'electromechanical systems',
#     'functional structure',
#     'micro electromechanical systems',
#     'printing',
#     'scalable',
#     'technique',
#     'energy',
#     'maximum',
#     'magnetic measurements',
#     'polymer',
#     'extrusion',
#     'present design',
#     'work',
#     'technology',
#     'casting',
#     'materials',
#     'solution casting',
#     'composite synthesis',
#     'design',
#     'products',
#     'different processing techniques',
#     'particle content',
#     'permanent magnet components',
#     'PE material',
#     'route',
#     'device',
#     'magnet composite',
#     'continuous length',
#     'manufacturing',
#     'magnet components',
#     'particles',
#     'components',
#     'measurements',
#     'phase'],
#    'terms': ['content',
#     'flexible filaments',
#     'system',
#     'polyethylene',
#     'shape',
#     'traditional manufacturing',
#     'fabrication',
#     'filament extrusion',
#     'composite materials',
#     'deterioration',
#     'efficiency',
#     'transport applications',
#     'compacted magnet',
#     'precursor',
#     'manufacturing restrictions',
#     'structure',
#     'matrix',
#     'technological applications',
#     'aerospace sector',
#     'processing techniques',
#     'homogeneous composites',
#     'related technologies',
#     'scalable design',
#     'synthesis',
#     'final device',
#     'spherical particles',
#     'properties',
#     'application',
#     'magnets',
#     'gas',
#     'composites',
#     'length',
#     'electromechanical systems',
#     'functional structure',
#     'micro electromechanical systems',
#     'printing',
#     'scalable',
#     'technique',
#     'energy',
#     'maximum',
#     'magnetic measurements',
#     'polymer',
#     'extrusion',
#     'present design',
#     'work',
#     'technology',
#     'casting',
#     'materials',
#     'solution casting',
#     'composite synthesis',
#     'design',
#     'products',
#     'different processing techniques',
#     'particle content',
#     'permanent magnet components',
#     'PE material',
#     'route',
#     'device',
#     'magnet composite',
#     'continuous length',
#     'manufacturing',
#     'magnet components',
#     'particles',
#     'components',
#     'measurements',
#     'phase'],
#    'pages': '465-473',
#    'volume': '19',
#    'reference_ids': ['pub.1003008311',
#     'pub.1059133440',
#     'pub.1016707234',
#     'pub.1052978629',
#     'pub.1038537710',
#     'pub.1008571100',
#     'pub.1006096355',
#     'pub.1044100206',
#     'pub.1006536023',
#     'pub.1036044049',
#     'pub.1084130443',
#     'pub.1091298697',
#     'pub.1030962280',
#     'pub.1071988007',
#     'pub.1053233274',
#     'pub.1084527494',
#     'pub.1057938439',
#     'pub.1011594972',
#     'pub.1016356469',
#     'pub.1061291865',
#     'pub.1044820020',
#     'pub.1046970790',
#     'pub.1085396124',
#     'pub.1058365449',
#     'pub.1021120712',
#     'pub.1027964092',
#     'pub.1029799271'],
#    'references': ['pub.1003008311',
#     'pub.1059133440',
#     'pub.1016707234',
#     'pub.1052978629',
#     'pub.1038537710',
#     'pub.1008571100',
#     'pub.1006096355',
#     'pub.1044100206',
#     'pub.1006536023',
#     'pub.1036044049',
#     'pub.1084130443',
#     'pub.1091298697',
#     'pub.1030962280',
#     'pub.1071988007',
#     'pub.1053233274',
#     'pub.1084527494',
#     'pub.1057938439',
#     'pub.1011594972',
#     'pub.1016356469',
#     'pub.1061291865',
#     'pub.1044820020',
#     'pub.1046970790',
#     'pub.1085396124',
#     'pub.1058365449',
#     'pub.1021120712',
#     'pub.1027964092',
#     'pub.1029799271'],
#    'date': '2018-12-31',
#    'times_cited': 3,
#    'publisher': 'Taylor & Francis',
#    'FOR_first': [{'id': '2209', 'name': '09 Engineering'}],
#    'pmid': '29887921',
#    'open_access': ['Open Access - all',
#     'Open Access - publisher',
#     'Open Access - published'],
#    'title': 'Development of permanent magnet MnAlC/polymer composites and flexible filament for bonding and 3D-printing technologies',
#    'recent_citations': 3,
#    'pmcid': 'PMC5990948',
#    'research_org_country_names': ['Sweden', 'Spain'],
#    'journal_lists': ['Norwegian register level 1',
#     'DOAJ',
#     'ERA 2015',
#     'PubMed'],
#    'research_org_countries': [{'id': 'ES', 'name': 'Spain'},
#     {'id': 'SE', 'name': 'Sweden'}],
#    'id': 'pub.1104296509',
#    'year': 2018,
#    'research_org_cities': [{'id': 2706003, 'name': 'Höganäs'},
#     {'id': 3117735, 'name': 'Madrid'}],
#    'doi': '10.1080/14686996.2018.1471321',
#    'research_orgs': [{'id': 'grid.482876.7',
#      'name': 'IMDEA Nanoscience',
#      'country_name': 'Spain'},
#     {'id': 'grid.424709.c',
#      'name': 'Höganäs (Sweden)',
#      'country_name': 'Sweden'}],
#    'linkout': 'https://www.tandfonline.com/doi/pdf/10.1080/14686996.2018.1471321?needAccess=true',
#    'issue': '1',
#    'open_access_categories': [{'id': 'oa_all',
#      'name': 'All OA',
#      'description': 'Article is freely available'},
#     {'id': 'gold_bronze',
#      'name': 'Bronze',
#      'description': 'Freely available on publisher page, but without an open licence'}],
#    'altmetric': 26,
#    'type': 'article',
#    'researchers': [{'id': 'ur.013741637062.76',
#      'last_name': 'Palmero',
#      'orcid_id': ['0000-0001-8223-3200'],
#      'research_orgs': ['grid.482876.7',
#       'grid.452504.2',
#       'grid.4711.3',
#       'grid.5718.b'],
#      'first_name': 'Ester Maria'},
#     {'id': 'ur.07414614063.30',
#      'last_name': 'Rial',
#      'research_orgs': ['grid.482876.7', 'grid.5515.4', 'grid.429045.e'],
#      'first_name': 'Javier'},
#     {'id': 'ur.013235051422.01',
#      'last_name': 'De Vicente',
#      'research_orgs': ['grid.482876.7'],
#      'first_name': 'Javier'},
#     {'id': 'ur.01027655236.11',
#      'last_name': 'Camarero',
#      'orcid_id': ['0000-0003-0078-7280'],
#      'research_orgs': ['grid.4444.0',
#       'grid.482876.7',
#       'grid.5515.4',
#       'grid.9621.c',
#       'grid.429045.e'],
#      'first_name': 'Julio'},
#     {'id': 'ur.014623751315.63',
#      'last_name': 'Skårman',
#      'research_orgs': ['grid.424709.c'],
#      'first_name': 'Björn'},
#     {'id': 'ur.01156222124.78',
#      'last_name': 'Vidarsson',
#      'research_orgs': ['grid.8761.8', 'grid.424709.c', 'grid.427935.e'],
#      'first_name': 'Hilmar'},
#     {'id': 'ur.071444746.01',
#      'last_name': 'Larsson',
#      'research_orgs': ['grid.4514.4',
#       'grid.424709.c',
#       'grid.28803.31',
#       'grid.8148.5'],
#      'first_name': 'Per-Olof'},
#     {'id': 'ur.0763542206.68',
#      'last_name': 'Bollero',
#      'orcid_id': ['0000-0002-3282-0981'],
#      'research_orgs': ['grid.482876.7',
#       'grid.4795.f',
#       'grid.457348.9',
#       'grid.14841.38',
#       'grid.464100.7',
#       'grid.5515.4',
#       'grid.420019.e',
#       'grid.9647.c',
#       'grid.429045.e'],
#      'first_name': 'Alberto'}],
#    'date_inserted': '2018-06-01',
#    'funder_countries': [{'id': 'ES', 'name': 'Spain'}]}]}

# %% [markdown]
# ## The Basics- control the fields you return

# %%
#A Basic Query - control the fields you return

dslquery("""
     search publications
     return publications[id+title+year]
     limit 5
""")
# Out:
# {'_stats': {'total_count': 101799147, 'limit': 5, 'offset': 0},
#  'publications': [{'id': 'pub.1113520473',
#    'year': 2019,
#    'title': '2. New Guinea Harpy Eagle'},
#   {'id': 'pub.1113353752', 'year': 2019, 'title': 'Session 1'},
#   {'id': 'pub.1110634575',
#    'year': 2019,
#    'title': 'Enhanced outcoupling in down-conversion white organic light-emitting diodes using imprinted microlens array films with breath figure patterns'},
#   {'id': 'pub.1113146182', 'year': 2019, 'title': 'Naked Lunch (1991)'},
#   {'id': 'pub.1113150437',
#    'year': 2019,
#    'title': '10. Religious Toleration in Pre-modern Empires'}]}

# %% [markdown]
# ## The Basics- make a mistake, and the DSL will tell you what fields that you could have used

# %%
#Make a mistake, and the DSL will tell you what fields are available

badquery = dslquery("""
     search publications 
     return publications[dois]
     limit 100
""")

print(badquery['errors']['query']['details'][0])
# Out:
# Semantic errors found:
# 	Field / Fieldset 'dois' is not present in Source 'publications'. Available fields: FOR,FOR_first,HRCS_HC,HRCS_RAC,RCDC,abstract,altmetric,altmetric_id,author_affiliations,book_doi,book_series_title,book_title,concepts,date,date_inserted,doi,field_citation_ratio,funder_countries,funders,id,issn,issue,journal,journal_lists,linkout,mesh_terms,open_access,open_access_categories,pages,pmcid,pmid,proceedings_title,publisher,recent_citations,reference_ids,references,relative_citation_ratio,research_org_cities,research_org_countries,research_org_country_names,research_org_state_codes,research_org_state_names,research_orgs,researchers,supporting_grant_ids,terms,times_cited,title,type,volume,year and available fieldsets: all,basics,book,extras

# %%
#A Basic Query - get all fields

dslquery("""
     search publications 
     return publications[all]
     limit 1
""")
# Out:
# {'_stats': {'total_count': 101798835, 'limit': 1, 'offset': 0},
#  '_warnings': ["Field 'terms' is deprecated in favor of concepts. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details",
#   "Field 'open_access' is deprecated in favor of open_access_categories. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details",
#   "Field 'references' is deprecated in favor of reference_ids. Please refer to https://docs.dimensions.ai/dsl/releasenotes.html for more details"],
#  'publications': [{'author_affiliations': [[{'first_name': 'Mark',
#       'last_name': 'Watson',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': []},
#      {'first_name': 'Martin',
#       'last_name': 'Gilbert',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': []}]],
#    'pages': '26-39',
#    'date': '2019-12-31',
#    'times_cited': 0,
#    'publisher': 'Cornell University Press',
#    'title': '2. New Guinea Harpy Eagle',
#    'recent_citations': 0,
#    'id': 'pub.1113520473',
#    'year': 2019,
#    'doi': '10.7591/9780801459382-004',
#    'open_access_categories': [{'id': 'closed',
#      'name': 'Closed',
#      'description': 'No freely available copy has been identified'}],
#    'type': 'chapter',
#    'book_doi': '10.7591/9780801459382',
#    'book_title': 'The Eagle Watchers',
#    'date_inserted': '2019-04-18'}]}

# %% [markdown]
# ## The Basics: you can search for full text in the full text or in abstracts

# %%
dslquery("""
     search publications for "nanotechnology"
       
     return publications
     limit 1
""")
# Out:
# {'_stats': {'total_count': 842486, 'limit': 1, 'offset': 0},
#  'publications': [{'volume': '20',
#    'id': 'pub.1112217617',
#    'journal': {'id': 'jour.1048844',
#     'title': 'Science and Technology of Advanced Materials'},
#    'issue': '1',
#    'year': 2019,
#    'author_affiliations': [[{'first_name': 'Hiroshi',
#       'last_name': 'Toshiyoshi',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'id': 'grid.26999.3d',
#         'name': 'University of Tokyo',
#         'city': 'Tokyo',
#         'city_id': 1850147,
#         'country': 'Japan',
#         'country_code': 'JP',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Suna',
#       'last_name': 'Ju',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'id': 'grid.255649.9',
#         'name': 'Ewha Womans University',
#         'city': 'Seoul',
#         'city_id': 1835848,
#         'country': 'South Korea',
#         'country_code': 'KR',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Hiroaki',
#       'last_name': 'Honma',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'id': 'grid.26999.3d',
#         'name': 'University of Tokyo',
#         'city': 'Tokyo',
#         'city_id': 1850147,
#         'country': 'Japan',
#         'country_code': 'JP',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Chang-Hyeon',
#       'last_name': 'Ji',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'id': 'grid.255649.9',
#         'name': 'Ewha Womans University',
#         'city': 'Seoul',
#         'city_id': 1835848,
#         'country': 'South Korea',
#         'country_code': 'KR',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Hiroyuki',
#       'last_name': 'Fujita',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'id': 'grid.458395.6',
#         'name': 'Tokyo City University',
#         'city': 'Tokyo',
#         'city_id': 1850147,
#         'country': 'Japan',
#         'country_code': 'JP',
#         'state': None,
#         'state_code': None}]}]],
#    'type': 'article',
#    'title': 'MEMS vibrational energy harvesters',
#    'pages': '124-143'}]}

# %%
dslquery("""
     search publications in title_abstract_only for "nanotechnology" 
     return publications
     limit 1
""")
# Out:
# {'_stats': {'total_count': 39390, 'limit': 1, 'offset': 0},
#  'publications': [{'author_affiliations': [[{'first_name': 'Katsuhiko',
#       'last_name': 'Ariga',
#       'orcid': "['0000-0002-2445-2955']",
#       'current_organization_id': 'grid.21941.3f',
#       'researcher_id': 'ur.01167705640.31',
#       'affiliations': [{'id': 'grid.21941.3f',
#         'name': 'National Institute for Materials Science',
#         'city': 'Tsukuba',
#         'city_id': 2110683,
#         'country': 'Japan',
#         'country_code': 'JP',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Michihiro',
#       'last_name': 'Nishikawa',
#       'orcid': '',
#       'current_organization_id': 'grid.21941.3f',
#       'researcher_id': 'ur.016537563446.05',
#       'affiliations': [{'id': 'grid.21941.3f',
#         'name': 'National Institute for Materials Science',
#         'city': 'Tsukuba',
#         'city_id': 2110683,
#         'country': 'Japan',
#         'country_code': 'JP',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Taizo',
#       'last_name': 'Mori',
#       'orcid': '',
#       'current_organization_id': 'grid.21941.3f',
#       'researcher_id': 'ur.01276370277.16',
#       'affiliations': [{'id': 'grid.21941.3f',
#         'name': 'National Institute for Materials Science',
#         'city': 'Tsukuba',
#         'city_id': 2110683,
#         'country': 'Japan',
#         'country_code': 'JP',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Jun',
#       'last_name': 'Takeya',
#       'orcid': '',
#       'current_organization_id': 'grid.26999.3d',
#       'researcher_id': 'ur.01361056216.65',
#       'affiliations': [{'id': 'grid.26999.3d',
#         'name': 'University of Tokyo',
#         'city': 'Tokyo',
#         'city_id': 1850147,
#         'country': 'Japan',
#         'country_code': 'JP',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Lok Kumar',
#       'last_name': 'Shrestha',
#       'orcid': "['0000-0003-2680-6291']",
#       'current_organization_id': 'grid.21941.3f',
#       'researcher_id': 'ur.01170654666.42',
#       'affiliations': [{'id': 'grid.21941.3f',
#         'name': 'National Institute for Materials Science',
#         'city': 'Tsukuba',
#         'city_id': 2110683,
#         'country': 'Japan',
#         'country_code': 'JP',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Jonathan P.',
#       'last_name': 'Hill',
#       'orcid': "['0000-0002-4229-5842']",
#       'current_organization_id': 'grid.21941.3f',
#       'researcher_id': 'ur.01142107721.94',
#       'affiliations': [{'id': 'grid.21941.3f',
#         'name': 'National Institute for Materials Science',
#         'city': 'Tsukuba',
#         'city_id': 2110683,
#         'country': 'Japan',
#         'country_code': 'JP',
#         'state': None,
#         'state_code': None}]}]],
#    'type': 'article',
#    'id': 'pub.1110633851',
#    'journal': {'id': 'jour.1048844',
#     'title': 'Science and Technology of Advanced Materials'},
#    'year': 2019,
#    'title': 'Self-assembly as a key player for materials nanoarchitectonics',
#    'pages': '51-95',
#    'issue': '1',
#    'volume': '20'}]}

# %% [markdown]
# ## The Basics - a simple author search

# %%
dslquery("""
     search publications in authors for "\\"Daniel Hook\\""
     return publications
     limit 10
""")
# Out:
# {'_stats': {'total_count': 49, 'limit': 10, 'offset': 0},
#  'publications': [{'id': 'pub.1115957159',
#    'year': 2019,
#    'journal': {'id': 'jour.1037553', 'title': 'PLoS ONE'},
#    'author_affiliations': [[{'first_name': 'David',
#       'last_name': 'Zeitlyn',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'id': 'grid.4991.5',
#         'name': 'University of Oxford',
#         'city': 'Oxford',
#         'city_id': 2640729,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Daniel W.',
#       'last_name': 'Hook',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'id': 'grid.452594.b',
#         'name': 'Digital Science (United Kingdom)',
#         'city': 'London',
#         'city_id': 2643743,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None},
#        {'id': 'grid.7445.2',
#         'name': 'Imperial College London',
#         'city': 'London',
#         'city_id': 2643743,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None},
#        {'id': 'grid.4367.6',
#         'name': 'Washington University in St. Louis',
#         'city': 'St Louis',
#         'city_id': 4407066,
#         'country': 'United States',
#         'country_code': 'US',
#         'state': 'Missouri',
#         'state_code': 'US-MO'}]}]],
#    'type': 'article',
#    'title': 'Perception, prestige and PageRank',
#    'pages': 'e0216783',
#    'volume': '14',
#    'issue': '5'},
#   {'id': 'pub.1108567148',
#    'year': 2019,
#    'author_affiliations': [[{'first_name': 'Carl M',
#       'last_name': 'Bender',
#       'orcid': "['0000-0002-3840-1155']",
#       'current_organization_id': 'grid.4367.6',
#       'researcher_id': 'ur.01310552610.52',
#       'affiliations': [{'name': 'Washington University in St. LouisUSA'}]},
#      {'first_name': 'Patrick E',
#       'last_name': 'Dorey',
#       'orcid': '',
#       'current_organization_id': 'grid.8250.f',
#       'researcher_id': 'ur.013031721717.97',
#       'affiliations': []},
#      {'first_name': 'Clare',
#       'last_name': 'Dunning',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': 'ur.016256640576.27',
#       'affiliations': []},
#      {'first_name': 'Andreas',
#       'last_name': 'Fring',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': []},
#      {'first_name': 'Daniel W',
#       'last_name': 'Hook',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': []},
#      {'first_name': 'Hugh F',
#       'last_name': 'Jones',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': []},
#      {'first_name': 'Sergii',
#       'last_name': 'Kuzhel',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': []},
#      {'first_name': 'Géza',
#       'last_name': 'Lévai',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': []},
#      {'first_name': 'Roberto',
#       'last_name': 'Tateo',
#       'orcid': "['0000-0002-9549-5450']",
#       'current_organization_id': 'grid.7605.4',
#       'researcher_id': 'ur.011444520764.30',
#       'affiliations': []}]],
#    'type': 'monograph',
#    'title': 'PT Symmetry'},
#   {'id': 'pub.1111011264',
#    'year': 2018,
#    'journal': {'id': 'jour.1047781', 'title': '2010 IEEE Sensors'},
#    'author_affiliations': [[{'first_name': 'Daniel',
#       'last_name': 'Hook',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'id': 'grid.20409.3f',
#         'name': 'Edinburgh Napier University',
#         'city': 'Edinburgh',
#         'city_id': 2650225,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'William',
#       'last_name': 'Laing',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'id': 'grid.20409.3f',
#         'name': 'Edinburgh Napier University',
#         'city': 'Edinburgh',
#         'city_id': 2650225,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Abdelfateh',
#       'last_name': 'Kerrouche',
#       'orcid': '',
#       'current_organization_id': 'grid.20409.3f',
#       'researcher_id': 'ur.016555103257.15',
#       'affiliations': [{'id': 'grid.20409.3f',
#         'name': 'Edinburgh Napier University',
#         'city': 'Edinburgh',
#         'city_id': 2650225,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Daniel',
#       'last_name': 'Barreto',
#       'orcid': "['0000-0003-4790-3250']",
#       'current_organization_id': 'grid.20409.3f',
#       'researcher_id': 'ur.012576057725.50',
#       'affiliations': [{'id': 'grid.20409.3f',
#         'name': 'Edinburgh Napier University',
#         'city': 'Edinburgh',
#         'city_id': 2650225,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Lourdes S. M.',
#       'last_name': 'Alwis',
#       'orcid': '',
#       'current_organization_id': 'grid.20409.3f',
#       'researcher_id': 'ur.010240513126.15',
#       'affiliations': [{'id': 'grid.20409.3f',
#         'name': 'Edinburgh Napier University',
#         'city': 'Edinburgh',
#         'city_id': 2650225,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None}]}]],
#    'type': 'proceeding',
#    'title': 'Optical Fiber Sensor Design for Ground Slope Movement Monitoring for Railway Safety Operations',
#    'pages': '1-4'},
#   {'id': 'pub.1106289502',
#    'year': 2018,
#    'journal': {'id': 'jour.1292498',
#     'title': 'Frontiers in Research Metrics and Analytics'},
#    'author_affiliations': [[{'first_name': 'Daniel W.',
#       'last_name': 'Hook',
#       'orcid': "['0000-0001-9746-1193']",
#       'current_organization_id': 'grid.7445.2',
#       'researcher_id': 'ur.01123321343.51',
#       'affiliations': [{'id': 'grid.452594.b',
#         'name': 'Digital Science (United Kingdom)',
#         'city': 'London',
#         'city_id': 2643743,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None},
#        {'id': 'grid.7445.2',
#         'name': 'Imperial College London',
#         'city': 'London',
#         'city_id': 2643743,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None},
#        {'id': 'grid.4367.6',
#         'name': 'Washington University in St. Louis',
#         'city': 'St Louis',
#         'city_id': 4407066,
#         'country': 'United States',
#         'country_code': 'US',
#         'state': 'Missouri',
#         'state_code': 'US-MO'}]},
#      {'first_name': 'Simon J.',
#       'last_name': 'Porter',
#       'orcid': "['0000-0002-6151-8423']",
#       'current_organization_id': 'grid.452594.b',
#       'researcher_id': 'ur.012016042104.74',
#       'affiliations': [{'id': 'grid.452594.b',
#         'name': 'Digital Science (United Kingdom)',
#         'city': 'London',
#         'city_id': 2643743,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Christian',
#       'last_name': 'Herzog',
#       'orcid': "['0000-0002-9983-0033']",
#       'current_organization_id': 'grid.452594.b',
#       'researcher_id': 'ur.014544122464.10',
#       'affiliations': [{'id': 'grid.452594.b',
#         'name': 'Digital Science (United Kingdom)',
#         'city': 'London',
#         'city_id': 2643743,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None}]}]],
#    'type': 'article',
#    'title': 'Dimensions: Building Context for Search and Evaluation',
#    'pages': '23',
#    'volume': '3'},
#   {'id': 'pub.1105321123',
#    'year': 2018,
#    'journal': {'id': 'jour.1091476', 'title': 'Contact Lens and Anterior Eye'},
#    'author_affiliations': [[{'first_name': 'Daniel',
#       'last_name': 'Hook',
#       'orcid': '',
#       'current_organization_id': 'grid.433688.2',
#       'researcher_id': 'ur.07403446145.09',
#       'affiliations': []},
#      {'first_name': 'Katarzyna',
#       'last_name': 'Wygladacz',
#       'orcid': '',
#       'current_organization_id': 'grid.433688.2',
#       'researcher_id': 'ur.0756356645.19',
#       'affiliations': []},
#      {'first_name': 'Marjorie',
#       'last_name': 'Rah',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': []}]],
#    'type': 'article',
#    'title': 'Assessment of the interaction between a natural wetting agent and silicone hydrogel contact lenses containing PVP using novel imaging techniques',
#    'pages': 's45',
#    'volume': '41'},
#   {'id': 'pub.1085413261',
#    'year': 2018,
#    'journal': {'id': 'jour.1312091',
#     'title': 'Journal of Biomedical Materials Research Part B Applied Biomaterials'},
#    'author_affiliations': [[{'first_name': 'Andrew J.',
#       'last_name': 'Hoteling',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': 'ur.01045401304.40',
#       'affiliations': [{'name': 'Vision Care, Bausch & Lomb Incorporated, Rochester, New York'}]},
#      {'first_name': 'William F.',
#       'last_name': 'Nichols',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'name': 'Vision Care, Bausch & Lomb Incorporated, Rochester, New York'}]},
#      {'first_name': 'Patricia S.',
#       'last_name': 'Harmon',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'name': 'Vision Care, Bausch & Lomb Incorporated, Rochester, New York'}]},
#      {'first_name': 'Shawn M.',
#       'last_name': 'Conlon',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'name': 'Vision Care, Bausch & Lomb Incorporated, Rochester, New York'}]},
#      {'first_name': 'Ivan M.',
#       'last_name': 'Nuñez',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'name': 'Vision Care, Bausch & Lomb Incorporated, Rochester, New York'}]},
#      {'first_name': 'Joseph W.',
#       'last_name': 'Hoff',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'name': 'Vision Care, Bausch & Lomb Incorporated, Rochester, New York'}]},
#      {'first_name': 'Orlando M.',
#       'last_name': 'Cabarcos',
#       'orcid': '',
#       'current_organization_id': 'grid.29857.31',
#       'researcher_id': 'ur.01112406573.51',
#       'affiliations': [{'name': 'Vision Care, Bausch & Lomb Incorporated, Rochester, New York'}]},
#      {'first_name': 'Robert B.',
#       'last_name': 'Steffen',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'name': 'Vision Care, Bausch & Lomb Incorporated, Rochester, New York'}]},
#      {'first_name': 'Daniel J.',
#       'last_name': 'Hook',
#       'orcid': '',
#       'current_organization_id': 'grid.433688.2',
#       'researcher_id': 'ur.07403446145.09',
#       'affiliations': [{'name': 'Vision Care, Bausch & Lomb Incorporated, Rochester, New York'}]}]],
#    'type': 'article',
#    'title': 'Characterization and quantitation of PVP content in a silicone hydrogel contact lens produced by dual‐phase polymerization processing',
#    'pages': '1064-1072',
#    'volume': '106',
#    'issue': '3'},
#   {'id': 'pub.1085511076',
#    'year': 2017,
#    'journal': {'id': 'jour.1053349', 'title': 'Physical Review A'},
#    'author_affiliations': [[{'first_name': 'Carl M.',
#       'last_name': 'Bender',
#       'orcid': "['0000-0002-3840-1155']",
#       'current_organization_id': 'grid.4367.6',
#       'researcher_id': 'ur.01310552610.52',
#       'affiliations': [{'id': 'grid.4367.6',
#         'name': 'Washington University in St. Louis',
#         'city': 'St Louis',
#         'city_id': 4407066,
#         'country': 'United States',
#         'country_code': 'US',
#         'state': 'Missouri',
#         'state_code': 'US-MO'}]},
#      {'first_name': 'Nima',
#       'last_name': 'Hassanpour',
#       'orcid': '',
#       'current_organization_id': 'grid.4367.6',
#       'researcher_id': 'ur.016700034171.07',
#       'affiliations': [{'id': 'grid.4367.6',
#         'name': 'Washington University in St. Louis',
#         'city': 'St Louis',
#         'city_id': 4407066,
#         'country': 'United States',
#         'country_code': 'US',
#         'state': 'Missouri',
#         'state_code': 'US-MO'}]},
#      {'first_name': 'Daniel W.',
#       'last_name': 'Hook',
#       'orcid': "['0000-0001-9746-1193']",
#       'current_organization_id': 'grid.7445.2',
#       'researcher_id': 'ur.01123321343.51',
#       'affiliations': [{'id': 'grid.4367.6',
#         'name': 'Washington University in St. Louis',
#         'city': 'St Louis',
#         'city_id': 4407066,
#         'country': 'United States',
#         'country_code': 'US',
#         'state': 'Missouri',
#         'state_code': 'US-MO'},
#        {'id': 'grid.7445.2',
#         'name': 'Imperial College London',
#         'city': 'London',
#         'city_id': 2643743,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'S. P.',
#       'last_name': 'Klevansky',
#       'orcid': '',
#       'current_organization_id': 'grid.7700.0',
#       'researcher_id': 'ur.011205262121.46',
#       'affiliations': [{'id': 'grid.7700.0',
#         'name': 'Heidelberg University',
#         'city': 'Heidelberg',
#         'city_id': 2907911,
#         'country': 'Germany',
#         'country_code': 'DE',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Christoph',
#       'last_name': 'Sünderhauf',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'id': 'grid.4367.6',
#         'name': 'Washington University in St. Louis',
#         'city': 'St Louis',
#         'city_id': 4407066,
#         'country': 'United States',
#         'country_code': 'US',
#         'state': 'Missouri',
#         'state_code': 'US-MO'},
#        {'id': 'grid.7700.0',
#         'name': 'Heidelberg University',
#         'city': 'Heidelberg',
#         'city_id': 2907911,
#         'country': 'Germany',
#         'country_code': 'DE',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Zichao',
#       'last_name': 'Wen',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'id': 'grid.4367.6',
#         'name': 'Washington University in St. Louis',
#         'city': 'St Louis',
#         'city_id': 4407066,
#         'country': 'United States',
#         'country_code': 'US',
#         'state': 'Missouri',
#         'state_code': 'US-MO'},
#        {'id': 'grid.410726.6',
#         'name': 'University of Chinese Academy of Sciences',
#         'city': 'Beijing',
#         'city_id': 1816670,
#         'country': 'China',
#         'country_code': 'CN',
#         'state': None,
#         'state_code': None},
#        {'id': 'grid.458463.8',
#         'name': 'Academy of Mathematics and Systems Science',
#         'city': 'Beijing',
#         'city_id': 1816670,
#         'country': 'China',
#         'country_code': 'CN',
#         'state': None,
#         'state_code': None}]}]],
#    'type': 'article',
#    'title': 'Behavior of eigenvalues in a region of broken PT symmetry',
#    'pages': '052113',
#    'volume': '95',
#    'issue': '5'},
#   {'id': 'pub.1059174631',
#    'year': 2016,
#    'journal': {'id': 'jour.1084797',
#     'title': 'Journal of Physics A: Mathematical and Theoretical'},
#    'author_affiliations': [[{'first_name': 'Carl M',
#       'last_name': 'Bender',
#       'orcid': "['0000-0002-3840-1155']",
#       'current_organization_id': 'grid.4367.6',
#       'researcher_id': 'ur.01310552610.52',
#       'affiliations': [{'id': 'grid.4367.6',
#         'name': 'Washington University in St. Louis',
#         'city': 'St Louis',
#         'city_id': 4407066,
#         'country': 'United States',
#         'country_code': 'US',
#         'state': 'Missouri',
#         'state_code': 'US-MO'},
#        {'id': 'grid.13097.3c',
#         'name': "King's College London",
#         'city': 'London',
#         'city_id': 2643743,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Daniel W',
#       'last_name': 'Hook',
#       'orcid': "['0000-0001-9746-1193']",
#       'current_organization_id': 'grid.7445.2',
#       'researcher_id': 'ur.01123321343.51',
#       'affiliations': []},
#      {'first_name': 'Nick E',
#       'last_name': 'Mavromatos',
#       'orcid': '',
#       'current_organization_id': 'grid.13097.3c',
#       'researcher_id': 'ur.013370754534.78',
#       'affiliations': [{'id': 'grid.13097.3c',
#         'name': "King's College London",
#         'city': 'London',
#         'city_id': 2643743,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None},
#        {'id': 'grid.9132.9',
#         'name': 'European Organization for Nuclear Research',
#         'city': 'Geneva',
#         'city_id': 2660646,
#         'country': 'Switzerland',
#         'country_code': 'CH',
#         'state': None,
#         'state_code': None}]},
#      {'first_name': 'Sarben',
#       'last_name': 'Sarkar',
#       'orcid': "['0000-0003-1369-7794']",
#       'current_organization_id': 'grid.13097.3c',
#       'researcher_id': 'ur.014114026641.24',
#       'affiliations': [{'id': 'grid.13097.3c',
#         'name': "King's College London",
#         'city': 'London',
#         'city_id': 2643743,
#         'country': 'United Kingdom',
#         'country_code': 'GB',
#         'state': None,
#         'state_code': None}]}]],
#    'type': 'article',
#    'title': '-symmetric interpretation of unstable effective potentials',
#    'pages': '45lt01',
#    'volume': '49',
#    'issue': '45'},
#   {'id': 'pub.1044133006',
#    'year': 2016,
#    'journal': {'id': 'jour.1313374', 'title': 'Clinical Ophthalmology'},
#    'author_affiliations': [[{'first_name': 'Katarzyna A',
#       'last_name': 'Wygladacz',
#       'orcid': '',
#       'current_organization_id': 'grid.433688.2',
#       'researcher_id': 'ur.0756356645.19',
#       'affiliations': [{'id': 'grid.433688.2',
#         'name': 'Bausch Health (United States)',
#         'city': 'Bridgewater',
#         'city_id': 8299576,
#         'country': 'United States',
#         'country_code': 'US',
#         'state': 'New Jersey',
#         'state_code': 'US-NJ'}]},
#      {'first_name': 'Daniel J',
#       'last_name': 'Hook',
#       'orcid': '',
#       'current_organization_id': 'grid.433688.2',
#       'researcher_id': 'ur.07403446145.09',
#       'affiliations': [{'id': 'grid.433688.2',
#         'name': 'Bausch Health (United States)',
#         'city': 'Bridgewater',
#         'city_id': 8299576,
#         'country': 'United States',
#         'country_code': 'US',
#         'state': 'New Jersey',
#         'state_code': 'US-NJ'}]}]],
#    'type': 'article',
#    'title': 'Visualization of a hyaluronan network on the surface of silicone-hydrogel materials',
#    'pages': '1423-1433',
#    'volume': 'Volume 10'},
#   {'id': 'pub.1055116418',
#    'year': 2015,
#    'journal': {'id': 'jour.1126508', 'title': 'Langmuir'},
#    'author_affiliations': [[{'first_name': 'Dustin T',
#       'last_name': 'McCall',
#       'orcid': '',
#       'current_organization_id': '',
#       'researcher_id': '',
#       'affiliations': [{'id': 'grid.273335.3',
#         'name': 'University at Buffalo, State University of New York',
#         'city': 'Buffalo',
#         'city_id': 5110629,
#         'country': 'United States',
#         'country_code': 'US',
#         'state': 'New York',
#         'state_code': 'US-NY'}]},
#      {'first_name': 'Yi',
#       'last_name': 'Zhang',
#       'orcid': '',
#       'current_organization_id': 'grid.273335.3',
#       'researcher_id': 'ur.01005654245.53',
#       'affiliations': [{'id': 'grid.273335.3',
#         'name': 'University at Buffalo, State University of New York',
#         'city': 'Buffalo',
#         'city_id': 5110629,
#         'country': 'United States',
#         'country_code': 'US',
#         'state': 'New York',
#         'state_code': 'US-NY'}]},
#      {'first_name': 'Daniel J',
#       'last_name': 'Hook',
#       'orcid': '',
#       'current_organization_id': 'grid.433688.2',
#       'researcher_id': 'ur.07403446145.09',
#       'affiliations': [{'name': 'Bausch + Lomb Incorporated, 1400 Goodman St. N., Rochester, New York 14609, United States.'}]},
#      {'first_name': 'Frank V',
#       'last_name': 'Bright',
#       'orcid': "['0000-0002-1500-5969']",
#       'current_organization_id': 'grid.273335.3',
#       'researcher_id': 'ur.0702116275.98',
#       'affiliations': [{'id': 'grid.273335.3',
#         'name': 'University at Buffalo, State University of New York',
#         'city': 'Buffalo',
#         'city_id': 5110629,
#         'country': 'United States',
#         'country_code': 'US',
#         'state': 'New York',
#         'state_code': 'US-NY'}]}]],
#    'type': 'article',
#    'title': 'Optimizing Pin-Printed and Hydrosilylated Microarray Spot Density on Porous Silicon Platforms.',
#    'pages': '11370-7',
#    'volume': '31',
#    'issue': '41'}]}

# %% [markdown]
# ## ..or search for a researcher by a specific id

# %%
#A Basic Query - or request just thoses that you want...

dslquery("""
     search publications 
     where researchers.id = "ur.013514345521.07"
       
     return publications[doi+researchers]
     limit 1
""")
# Out:
# {'_stats': {'total_count': 6, 'limit': 1, 'offset': 0},
#  'publications': [{'doi': '10.3390/v10050250',
#    'researchers': [{'id': 'ur.013514345521.07',
#      'last_name': 'Parveen',
#      'research_orgs': ['grid.5949.1', 'grid.5596.f', 'grid.5371.0'],
#      'first_name': 'Nagma'},
#     {'id': 'ur.01045210614.25',
#      'last_name': 'Borrenberghs',
#      'research_orgs': ['grid.5596.f'],
#      'first_name': 'Doortje'},
#     {'id': 'ur.01123422665.94',
#      'last_name': 'Rocha',
#      'orcid_id': ['0000-0003-1258-9396'],
#      'research_orgs': ['grid.5949.1',
#       'grid.5596.f',
#       'grid.461801.a',
#       'grid.9983.b',
#       'grid.467824.b'],
#      'first_name': 'Susana Ferreira'},
#     {'id': 'ur.01361166556.89',
#      'last_name': 'Hendrix',
#      'orcid_id': ['0000-0001-5731-1297'],
#      'research_orgs': ['grid.12155.32', 'grid.5596.f', 'grid.5252.0'],
#      'first_name': 'Jelle'}]}]}

# %% [markdown]
# ## You can also query by facets

# %%
dslquery("""
     search publications 
     return FOR_first 
""")
# Out:
# {'_stats': {'total_count': 101799147},
#  'FOR_first': [{'id': '2211',
#    'count': 15537130,
#    'name': '11 Medical and Health Sciences'},
#   {'id': '2206', 'count': 6152625, 'name': '06 Biological Sciences'},
#   {'id': '2209', 'count': 5871028, 'name': '09 Engineering'},
#   {'id': '2203', 'count': 4478669, 'name': '03 Chemical Sciences'},
#   {'id': '2208',
#    'count': 3598505,
#    'name': '08 Information and Computing Sciences'},
#   {'id': '2202', 'count': 2322005, 'name': '02 Physical Sciences'},
#   {'id': '2201', 'count': 2061821, 'name': '01 Mathematical Sciences'},
#   {'id': '2217',
#    'count': 2023510,
#    'name': '17 Psychology and Cognitive Sciences'},
#   {'id': '2216', 'count': 1239591, 'name': '16 Studies in Human Society'},
#   {'id': '2204', 'count': 1079460, 'name': '04 Earth Sciences'},
#   {'id': '2210', 'count': 940462, 'name': '10 Technology'},
#   {'id': '2214', 'count': 911659, 'name': '14 Economics'},
#   {'id': '2205', 'count': 758964, 'name': '05 Environmental Sciences'},
#   {'id': '2221', 'count': 733066, 'name': '21 History and Archaeology'},
#   {'id': '2220',
#    'count': 641487,
#    'name': '20 Language, Communication and Culture'},
#   {'id': '2213', 'count': 597106, 'name': '13 Education'},
#   {'id': '2215',
#    'count': 583097,
#    'name': '15 Commerce, Management, Tourism and Services'},
#   {'id': '2207',
#    'count': 357327,
#    'name': '07 Agricultural and Veterinary Sciences'},
#   {'id': '2218', 'count': 299089, 'name': '18 Law and Legal Studies'},
#   {'id': '2222',
#    'count': 274546,
#    'name': '22 Philosophy and Religious Studies'}]}

# %% [markdown]
# ## You can return up to 1000 facet rows

# %%
dslquery("""
     search publications for "nanotechnology"
     return year limit 1000
""")
# Out:
# {'_stats': {'total_count': 842486},
#  'year': [{'id': 2018, 'count': 84405},
#   {'id': 2017, 'count': 77493},
#   {'id': 2016, 'count': 76869},
#   {'id': 2015, 'count': 72869},
#   {'id': 2014, 'count': 68182},
#   {'id': 2013, 'count': 65409},
#   {'id': 2012, 'count': 56060},
#   {'id': 2011, 'count': 55050},
#   {'id': 2019, 'count': 47543},
#   {'id': 2008, 'count': 45161},
#   {'id': 2010, 'count': 40912},
#   {'id': 2009, 'count': 39731},
#   {'id': 2007, 'count': 26017},
#   {'id': 2006, 'count': 22011},
#   {'id': 2005, 'count': 16942},
#   {'id': 2004, 'count': 12302},
#   {'id': 2003, 'count': 7844},
#   {'id': 2002, 'count': 6040},
#   {'id': 2001, 'count': 4049},
#   {'id': 2000, 'count': 2642},
#   {'id': 1999, 'count': 2089},
#   {'id': 1998, 'count': 1757},
#   {'id': 1996, 'count': 1498},
#   {'id': 1997, 'count': 1321},
#   {'id': 1994, 'count': 1288},
#   {'id': 1995, 'count': 1064},
#   {'id': 1993, 'count': 1056},
#   {'id': 1992, 'count': 861},
#   {'id': 1991, 'count': 858},
#   {'id': 1988, 'count': 535},
#   {'id': 1990, 'count': 506},
#   {'id': 1989, 'count': 422},
#   {'id': 1985, 'count': 373},
#   {'id': 1987, 'count': 373},
#   {'id': 1986, 'count': 305},
#   {'id': 1983, 'count': 292},
#   {'id': 1984, 'count': 175},
#   {'id': 1970, 'count': 15},
#   {'id': 1899, 'count': 6},
#   {'id': 1973, 'count': 6},
#   {'id': 1980, 'count': 6},
#   {'id': 1969, 'count': 5},
#   {'id': 1978, 'count': 5},
#   {'id': 1971, 'count': 4},
#   {'id': 1966, 'count': 3},
#   {'id': 1972, 'count': 3},
#   {'id': 1975, 'count': 3},
#   {'id': 1955, 'count': 2},
#   {'id': 1957, 'count': 2},
#   {'id': 1958, 'count': 2},
#   {'id': 1974, 'count': 2},
#   {'id': 1870, 'count': 1},
#   {'id': 1949, 'count': 1},
#   {'id': 1960, 'count': 1},
#   {'id': 1962, 'count': 1},
#   {'id': 1964, 'count': 1},
#   {'id': 1965, 'count': 1},
#   {'id': 1976, 'count': 1},
#   {'id': 1977, 'count': 1},
#   {'id': 1979, 'count': 1},
#   {'id': 1982, 'count': 1}]}

# %% [markdown]
# ## Just make a mistake, and you will ge the complete list of available facets

# %%
dslquery("""
     search publications 
     return years 
""")
# Out:
# {'errors': {'query': {'header': 'Semantic Error',
#    'details': ["Semantic errors found:\n\tFacet 'years' is not present in source 'publications'. Available facets are: FOR,FOR_first,HRCS_HC,HRCS_RAC,RCDC,funder_countries,funders,journal,mesh_terms,open_access_categories,publisher,research_org_cities,research_org_countries,research_org_state_codes,research_orgs,researchers,type,year"],
#    'query': '\n     search publications \n     return years \n'}}}

# %%
import pandas as pd
pd.DataFrame(dslquery("""
     search publications for "nanotechnology"
     return publications[title+altmetric] 
     limit 10
""")['publications'])
# Out:
#    altmetric                                              title
# 0        2.0                 MEMS vibrational energy harvesters
# 1        NaN  7. Searching for a New Role in East Asian Regi...
# 2       92.0  Self-assembly as a key player for materials na...
# 3        NaN  Cancer Immunotherapy Therapeutic Manipulation ...
# 4       57.0  Recent advances on fluorescent biomarkers of n...
# 5        NaN  54. “Moral Questions of an Altogether Differen...
# 6        NaN    9. Disability Rights Approach toward Bioethics?
# 7       54.0  Stretchable electronics: functional materials,...
# 8        2.0  Thermoelectric properties of sorted semiconduc...
# 9        NaN    Fifteen. Threshold 9? Teaching Possible Futures

# %% [markdown]
# ---
# # Want to learn more?
#
# Check out the [Dimensions API Lab](https://digital-science.github.io/dimensions-api-lab/) website, which contains many tutorials and reusable Jupyter notebooks for scholarly data analytics.
